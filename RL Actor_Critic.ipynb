# %% [markdown]
# ## PPO

# %% [markdown]
# ### Imports

# %%
import os
import numpy as np
import pandas as pd
import torch as T
import torch.nn as nn
import torch.optim as optim
from torch.distributions import Normal 

from gym import Env
from gym.spaces import Discrete, Box

import cvxpy as cp

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ### PPO Memory Class

# %%
#Code inspired by https://www.youtube.com/watch?v=K2qjAixgLqk
class PPOMemory:
    def __init__(self, batch_size):
        self.states = []
        self.probs = []
        self.vals = []
        self.actions = []
        self.rewards =[]
        self.dones =[]

        self.batch_size = batch_size
    
    def generate_batches(self):
        n_states = len(self.states)
        batch_start = np.arange(0, n_states, self.batch_size)
        indices = np.arange(n_states, dtype= np.int64)
        np.random.shuffle(indices)
        batches = [indices[i:i + self.batch_size] for i in batch_start][0]

        return np.array(self.states),\
                np.array(self.actions),\
                np.array(self.probs),\
                np.array(self.vals),\
                np.array(self.rewards),\
                np.array(self.dones),\
                batches
    def store_memory(self, state, action, prob, val, reward, done):
        self.states.append(state)
        self.actions.append(action)
        self.probs.append(prob)
        self.vals.append(val)
        self.rewards.append(reward)
        self.dones.append(done)
    
    def clear_memory(self):
        self.states = []
        self.probs = []
        self.actions =[]
        self.rewards = []
        self.dones = []
        self.vals =[]

class ActorNetwork(nn.Module):
    def __init__(self, n_actions, input_dims, alpha, fc1_dims=256, fc2_dims=256, chkpt_dir='checkpoint_directory/'):
        super(ActorNetwork, self).__init__()

        self.checkpoint_file = os.path.join(chkpt_dir, 'actor_torch_ppo')
        self.input_layer = nn.Linear(input_dims, fc1_dims)
        self.hidden_1 = nn.Linear(fc1_dims,fc2_dims)
        self.mean = nn.Linear(fc2_dims,n_actions)
        self.std = nn.Linear(fc2_dims, n_actions)

        self.optimizer = optim.Adam(self.parameters(), lr=alpha)
        self.device = T.device('cuda:0' if T.cuda.is_available() else 'cpu')
        self.to(self.device)
    
    def forward(self, state):
        input = self.input_layer(state)
        output = nn.functional.relu(input)
        h1 = self.hidden_1(output)
        h1_output = nn.functional.relu(h1)
        mean = self.mean(h1_output)
        # std = nn.functional.softplus(T.exp(self.std(h1_output)))  #ensures that the std is positive
        std = nn.functional.softplus(self.std(h1_output))
        return mean.flatten(), std.flatten()

    def save_checkpoint(self):
        T.save(self.state_dict(), self.checkpoint_file)
    def load_checkpoint(self):
        self.load_state_dict(T.load(self.checkpoint_file))

class CriticNetwork(nn.Module):
    def __init__(self, input_dims, alpha, fc1_dims=256, fc2_dims=256, chkpt_dir = 'checkpoint_directory/'):
        super(CriticNetwork, self).__init__()
        self.checkpoint_file = os.path.join(chkpt_dir, 'critic_torch_ppo')
        
        self.critic = nn.Sequential(
                                    nn.Linear(input_dims, fc1_dims),
                                    nn.ReLU(),
                                    nn.Linear(fc1_dims, fc2_dims),
                                    nn.ReLU(),
                                    nn.Linear(fc2_dims, 1)
        )

        self.optimizer = optim.Adam(self.parameters(), lr = alpha)
        self.device = T.device('cuda:0' if T.cuda.is_available() else 'cpu')

    def forward(self, state):
        value = self.critic(state)

        return value
    def save_checkpoint(self):
        T.save(self.state_dict(), self.checkpoint_file)
        
    def load_checkpoint(self):
        self.load_state_dict(T.load(self.checkpoint_file))

class Agent:
    def __init__(self, n_actions, input_dims, gamma=0.99, alpha=0.0003, gae_lambda=0.95, 
                 policy_clip=0.1, batch_size=64, N=2048, n_epochs =10):
        
        self.gamma = gamma
        self.gae_lambda = gae_lambda
        self.policy_clip = policy_clip
        self.n_epochs = n_epochs

        self.actor = ActorNetwork(n_actions, input_dims, alpha)
        self.critic = CriticNetwork(input_dims, alpha)
        self.memory = PPOMemory(batch_size)
    
    def remember(self, state, action, probs, vals, reward, done):
        self.memory.store_memory(state, action, probs, vals, reward, done)
    
    def save_models(self):
        # print('.....saving models.....')
        self.actor.save_checkpoint()
        self.critic.save_checkpoint()

    def load_models(self):
        print('.....loading models.....')
        self.actor.load_checkpoint()
        self.critic.load_checkpoint()
    
    def choose_action(self, observation):
        state = T.tensor([observation], dtype=T.float).to(self.actor.device)
        mean_actions, std_actions = self.actor(state)
        value = self.critic(state)

        dist = Normal(mean_actions, std_actions)
        sampled_actions = dist.sample()
        probs = dist.log_prob(sampled_actions)
        probs = probs.detach().numpy()
    
        action = sampled_actions.numpy()

        value = T.squeeze(value).item()

        return action, probs, value, #mean_actions, std_actions
    
    def learn(self):
        for _ in range(self.n_epochs):
            state_arr, action_arr, old_probs_arr, vals_arr, reward_arr, done_arr, batches = self.memory.generate_batches()

            values = vals_arr

            advantage = np.zeros(len(reward_arr), dtype = np.float32)

            for t in range(len(reward_arr)-1):
                discount = 1
                a_t=0
                for k in range(t, len(reward_arr)-1):
                    a_t += discount*(reward_arr[k] + self.gamma*values[k+1]* (1-int(done_arr[k])) - values[k])
                    discount *= self.gamma * self.gae_lambda
                advantage[t] = a_t
            
            advantage = T.tensor(advantage).to(self.actor.device)
            values = T.tensor(values).to(self.actor.device)
            for batch in batches:
                states = T.tensor(state_arr[batch], dtype = T.float).to(self.actor.device)
                old_probs = T.tensor(old_probs_arr[batch]).to(self.actor.device)
                actions = T.tensor(action_arr[batch]).to(self.actor.device)  
                print('states', states)
                mean_actions, std_actions = self.actor(states)
                print('mean_actions', mean_actions)
                print('std_actions',std_actions)
                dist = Normal(mean_actions, std_actions)
                new_probs = dist.log_prob(actions)
                prob_ratio = new_probs.exp() / old_probs.exp()

                critic_value = self.critic(states)
                critic_value = T.squeeze(critic_value)

                weighted_probs = advantage[batch] *prob_ratio
                weighted_clipped_probs = T.clamp(prob_ratio, 1-self.policy_clip, 1+self.policy_clip) * advantage[batch]
                actor_loss = -T.min(weighted_probs, weighted_clipped_probs).mean()

                returns = advantage[batch] + values[batch]
                critic_loss = (returns-critic_value)**2
                critic_loss = critic_loss.mean()

                total_loss = actor_loss + 0.5*critic_loss
                self.actor.optimizer.zero_grad()
                self.critic.optimizer.zero_grad()
                total_loss.backward()
                self.actor.optimizer.step()
                self.critic.optimizer.step()
        self.memory.clear_memory()

# %%
class Environment(Env):
    def __init__(self):
        self.observation_space = Box(low=-np.inf, high=np.inf)
        self.action_space = Box(np.array([-np.inf, -np.inf]), np.array([np.inf, np.inf]))
        self.asset_length = 0
        self.cur_mu =[]
        self.cur_var = []
        self.portfolio_index=[]
        self.portfolio_mu=[]
        self.portfolio_Q =[]
        
    def step(self, action, stock_vector, df_Q, old_observation, mvo_gamma, MVO, derivative, find_stock):
        self.cur_mu.append(action[0])
        self.cur_var.append(action[1])
        self.portfolio_index, self.portfolio_mu, self.portfolio_Q = find_stock(self.cur_mu[-1],self.cur_var[-1], stock_vector, df_Q, self.portfolio_index, self.portfolio_mu, self.portfolio_Q)

        w, self.state = MVO(np.array(self.portfolio_mu), self.portfolio_Q, mvo_gamma) 
        
        # self.transition = derivative(self.portfolio_mu,self.portfolio_Q, mvo_gamma, w)
        # reward = self.transition.item()

        self.transition = np.exp(self.state[0] - old_observation[0])
        reward = self.transition

        self.asset_length += 1
        self.done = (self.asset_length >= 50)

        return self.state, reward, self.done, self.portfolio_index 
    
    def reset(self):
        self.state = np.array([0])
        self.asset_length = 0
        self.cur_mu =[]
        self.cur_var = []
        self.portfolio_index=[]
        self.portfolio_mu=[]
        self.portfolio_Q =[]
        return self.state

# %%
def find_stock(mu,var, stock_vector, df_Q, portfolio_index, portfolio_mu, portfolio_Q):

    # combine predicted mu and var into 2-D array
    stock = np.hstack((mu,var))

    # initialize distance
    smallest_distance = np.inf

    # for all the 2-D stocks in the 1000 synthetic dataset,
    # calculate the euclidean distance from predicted stock
    for i,s in enumerate(stock_vector):
        distance = np.linalg.norm(stock - s)

        # choose stock that is closest distance to predicted stock
        # do not choose a stock that has already been chosen
        if (distance < smallest_distance) and (i not in portfolio_index):
            smallest_distance = distance
            stock_index = i
    
    # find chosen stock mu and append
    stock_mu = stock_vector[i][0]
    portfolio_mu.append(stock_mu)

    # append chosen stock index to portfolio index
    portfolio_index.append(stock_index)

    # apped chosen stock to current portfolio Q matrix
    portfolio_Q = df_Q[portfolio_index].loc[portfolio_index]
    portfolio_Q = np.array(portfolio_Q)

    return portfolio_index, portfolio_mu, portfolio_Q

# %%
def MVO(mu,Q,gamma=1):

    # number of stocks 
    n = len(mu)

    # if there is only one stock in the portfolio,
    # the matrix multiplication is different as Q is not a matrix but a 1-D vector
    if n == 1:

      # define weights
      w = cp.Variable(n)

      # define constraints
      constraints = [
          cp.sum(w) == 1, # Sum to 1
          w>=0 # Disallow Short Sales
      ]

      # objective function
      risk = w*Q
      targetRet=gamma*mu@w
      prob = cp.Problem(cp.Maximize(targetRet - risk), constraints=constraints)
      prob.solve()
      
      return w.value,targetRet.value-risk.value
    
    # if there are multiple stocks in the portfolio,
    # the matrix multiplication is quad_form as Q is a (n,n) matrix

    else:
      # define weights
      w = cp.Variable(n)

      # define constraints
      constraints = [
          cp.sum(w) == 1, # Sum to 1
          w>=0 # Disallow Short Sales
      ]

      # objective Function
      risk = cp.quad_form(w, Q)
      targetRet=gamma*mu.T@w
      prob = cp.Problem(cp.Maximize(targetRet - risk), constraints=constraints)
      prob.solve()

      return w.value,[targetRet.value-risk.value]

# %%
def derivative(mu,Q,gamma,w):

  # initialize risk
  risk=0

  # if portfolio has one stock,
  # derivative reduces to 1-D vector multiplication
  if len(mu)<=1:
     return (mu*gamma) - Q*w


  # if portfolio has more than one stock,
  # perform element-wise multiplication of Q-matrix with weights
  else:
    for i in range(len(mu)):
        risk+=Q[i][-1]*w[i]
    Ret=mu[-1]*gamma
        # Ret+=mu[-1]*gamma
    return Ret-risk

# %% [markdown]
# ## Load Data

# %%
path_to_data = 'Data\synthetic1000'
date = '2016-02-07'
df_mu = np.loadtxt('{}/{}/mu'.format(path_to_data, date))
df_Q = np.loadtxt('{}/{}/Q'.format(path_to_data, date))
df_Q = pd.DataFrame(df_Q)


# get the variance for each stock from the Q-matrix
# variance is the diagonal of the Q-matrix
df_var = []
for i in range(df_Q.shape[0]):
    for j in range(df_Q.shape[1]):
        if i==j:
            df_var.append(df_Q[i][j])
df_var = np.array(df_var)

# combine the mu and variance of each stock
# used to calculate the euclidean distance of predicted stock
stock_vector = []
for i in range(len(df_mu)):
    temp = np.hstack((df_mu[i],df_var[i]))
    stock_vector.append(temp)
stock_vector = np.array(stock_vector)

# %% [markdown]
# ## Constants

# %%
# define Environment object
env = Environment()

# learning interval
N = 500

# learning parameters
batch_size = 64
n_epochs = 10
alpha = 0.0003
gamma = 0.99
gae_lambda = 0.95
mvo_gamma =1 

# define number of actions for Actor
n_actions = env.action_space.shape[0]
# define input dimensions for Actor and Critic
input_dims = env.observation_space.shape[0]

# define Agent object
agent = Agent(n_actions, input_dims, gamma=gamma, alpha=alpha, gae_lambda=gae_lambda, 
                 policy_clip=0.1, batch_size=batch_size, N=N, n_epochs = n_epochs)

# training loop parameters
n_games = 800
best_score = -np.inf
score_history = []
learn_iters = 0
avg_score = 0
n_steps = 0
best_50_MVO = -np.inf
best_50_index = []

# %% [markdown]
# ## Main

# %%
# Training Loop for RL
for i in range(n_games):
    
    # reset the environment
    observation = env.reset()
    done = False

    # score tracks the total accumulated reward
    score = 0
    # stock counter to indicate when 50 stocks are reached
    stock_counter=0


    # start Agent loop
    while not done:
        # observe the environment and let Agent choose an action
        action, probs, value = agent.choose_action(observation)   
        # step the environment by updating new state space, reward recieved, and updating done
        observation_, reward, done, portfolio_index = env.step(action, stock_vector, df_Q, observation, mvo_gamma, MVO, derivative, find_stock)

        # increment n_steps
        n_steps+=1
        #increment reward total
        score+= reward
        
        # store (S,A,R,S') sequence in memory
        agent.remember(observation, action, probs, value, reward, done)

        # if total training steps can be divided by learning interval
        # perform gradient ascent in Agent
        if n_steps % N == 0:
            agent.learn()
            learn_iters+=1
        
        # store new observation as current observation
        observation = observation_

        # accumulate total rewards
        score_history.append(score)
        # get the average of the last 100 rewards
        avg_score=np.mean(score_history[-100:])
        # update the stock counter
        stock_counter+=1

        # when the RL is predicting the 50th stock in the portfolio
        # and the predicted MVO value is the highest yet
        if (stock_counter==49) and (observation[0] > best_50_MVO):
            best_50_index = portfolio_index
            best_50_MVO = observation

        # if the average score is better than the best
        # average score, than save the agent models
        if avg_score > best_score:
            best_score = avg_score
            agent.save_models()
        
    print('best_50_MVO', best_50_MVO)
    # print('episode', i, 'score%.1f' % score, 'avg score%.1f' % avg_score,
    #           'time_steps', n_steps, 'learning_steps', learn_iters)
    print('episode', i, 'score', score, 'avg score', avg_score,
            'time_steps', n_steps, 'learning_steps', learn_iters)
# Out:
# best_50_MVO [-19.067868476299974]
# episode 0 score 150.37668627776674 avg score 123.35528560759238 time_steps 550 learning_steps 0
# best_50_MVO [-19.067868476299967]
# episode 1 score 150.37668614154927 avg score 123.35636661936687 time_steps 600 learning_steps 0
# best_50_MVO [-19.067868476299967]
# episode 2 score 150.37668627776674 avg score 123.35636661936687 time_steps 650 learning_steps 0
# best_50_MVO [-19.067868476299967]
# episode 3 score 150.37668627776674 avg score 123.3563825099025 time_steps 700 learning_steps 0
# best_50_MVO [-19.067868476299967]
# episode 4 score 150.37668627776674 avg score 123.3563825099025 time_steps 750 learning_steps 0
# best_50_MVO [-19.067868476299967]
# episode 5 score 150.37668614154927 avg score 123.35636661936687 time_steps 800 learning_steps 0
# best_50_MVO [-19.067868476299967]
# episode 6 score 150.37668627776674 avg score 123.35636661936687 time_steps 850 learning_steps 0
# best_50_MVO [-19.067868476299967]
# episode 7 score 150.37668627776674 avg score 123.3563825099025 time_steps 900 learning_steps 0
# best_50_MVO [-19.067868476299967]
# episode 8 score 150.37668627776674 avg score 123.3563825099025 time_steps 950 learning_steps 0
# states tensor([-19.1732])
# mean_actions tensor([9.2500, 5.9243], grad_fn=<ViewBackward0>)
# std_actions tensor([0.0826, 0.2803], grad_fn=<SoftplusBackward0>)
# states tensor([-19.6794])
# mean_actions tensor([9.4964, 6.0800], grad_fn=<ViewBackward0>)
# std_actions tensor([0.0776, 0.2728], grad_fn=<SoftplusBackward0>)
# states tensor([-19.2442])
# mean_actions tensor([9.9262, 5.9158], grad_fn=<ViewBackward0>)
# std_actions tensor([0.0764, 0.2840], grad_fn=<SoftplusBackward0>)
# states tensor([-19.1942])
# mean_actions tensor([10.4799,  5.8732], grad_fn=<ViewBackward0>)
# std_actions tensor([0.0721, 0.2890], grad_fn=<SoftplusBackward0>)
# states tensor([-19.1623])
# mean_actions tensor([10.9800,  5.8383], grad_fn=<ViewBackward0>)
# std_actions tensor([0.0681, 0.2940], grad_fn=<SoftplusBackward0>)
# states tensor([-19.0883])
# mean_actions tensor([11.4019,  5.7930], grad_fn=<ViewBackward0>)
# std_actions tensor([0.0651, 0.2993], grad_fn=<SoftplusBackward0>)
# states tensor([-19.2015])
# mean_actions tensor([11.9540,  6.7969], grad_fn=<ViewBackward0>)
# std_actions tensor([0.0515, 0.3366], grad_fn=<SoftplusBackward0>)
# states tensor([-19.1889])
# mean_actions tensor([12.3432,  7.5961], grad_fn=<ViewBackward0>)
# std_actions tensor([0.0428, 0.3800], grad_fn=<SoftplusBackward0>)
# states tensor([-19.3703])
# mean_actions tensor([12.7992,  8.3889], grad_fn=<ViewBackward0>)
# std_actions tensor([0.0356, 0.4126], grad_fn=<SoftplusBackward0>)
# states tensor([-20.5210])
# mean_actions tensor([13.8791,  9.5726], grad_fn=<ViewBackward0>)
# std_actions tensor([0.0250, 0.4338], grad_fn=<SoftplusBackward0>)
# states tensor([-19.2979])
# mean_actions tensor([13.3148,  9.5839], grad_fn=<ViewBackward0>)
# std_actions tensor([0.0269, 0.4818], grad_fn=<SoftplusBackward0>)
# states tensor([-19.5918])
# mean_actions tensor([13.7582, 10.2524], grad_fn=<ViewBackward0>)
# std_actions tensor([0.0219, 0.5085], grad_fn=<SoftplusBackward0>)
# states tensor([-19.1170])
# mean_actions tensor([13.6352, 10.4661], grad_fn=<ViewBackward0>)
# std_actions tensor([0.0210, 0.5403], grad_fn=<SoftplusBackward0>)
# states tensor([-19.3420])
# mean_actions tensor([13.9882, 11.0028], grad_fn=<ViewBackward0>)
# std_actions tensor([0.0176, 0.5623], grad_fn=<SoftplusBackward0>)
# states tensor([-21.7770])
# mean_actions tensor([15.9480, 12.8084], grad_fn=<ViewBackward0>)
# std_actions tensor([0.0093, 0.5679], grad_fn=<SoftplusBackward0>)
# states tensor([-20.5210])
# mean_actions tensor([15.1932, 12.4262], grad_fn=<ViewBackward0>)
# std_actions tensor([0.0108, 0.5979], grad_fn=<SoftplusBackward0>)
# states tensor([-19.6282])
# mean_actions tensor([14.6748, 12.1940], grad_fn=<ViewBackward0>)
# std_actions tensor([0.0118, 0.6221], grad_fn=<SoftplusBackward0>)
# states tensor([-19.1416])
# mean_actions tensor([14.4385, 12.1619], grad_fn=<ViewBackward0>)
# std_actions tensor([0.0121, 0.6424], grad_fn=<SoftplusBackward0>)
# states tensor([-19.3703])
# mean_actions tensor([14.7305, 12.5527], grad_fn=<ViewBackward0>)
# std_actions tensor([0.0106, 0.6592], grad_fn=<SoftplusBackward0>)
# states tensor([-19.1139])
# mean_actions tensor([14.6424, 12.6045], grad_fn=<ViewBackward0>)
# std_actions tensor([0.0105, 0.6760], grad_fn=<SoftplusBackward0>)
# states tensor([-20.2676])
# mean_actions tensor([15.6294, 13.5756], grad_fn=<ViewBackward0>)
# std_actions tensor([0.0075, 0.6889], grad_fn=<SoftplusBackward0>)
# states tensor([-19.1732])
# mean_actions tensor([14.8725, 13.0198], grad_fn=<ViewBackward0>)
# std_actions tensor([0.0092, 0.7043], grad_fn=<SoftplusBackward0>)
# states tensor([-19.1129])
# mean_actions tensor([14.9044, 13.1392], grad_fn=<ViewBackward0>)
# std_actions tensor([0.0089, 0.7167], grad_fn=<SoftplusBackward0>)
# states tensor([-27.7981])
# mean_actions tensor([21.7823, 19.3323], grad_fn=<ViewBackward0>)
# std_actions tensor([0.0010, 0.7255], grad_fn=<SoftplusBackward0>)
# states tensor([-19.1883])
# mean_actions tensor([15.0993, 13.4679], grad_fn=<ViewBackward0>)
# std_actions tensor([0.0080, 0.7385], grad_fn=<SoftplusBackward0>)
# states tensor([-19.7683])
# mean_actions tensor([15.6161, 13.9977], grad_fn=<ViewBackward0>)
# std_actions tensor([0.0067, 0.7489], grad_fn=<SoftplusBackward0>)
# states tensor([-19.4103])
# mean_actions tensor([15.3865, 13.8515], grad_fn=<ViewBackward0>)
# std_actions tensor([0.0070, 0.7572], grad_fn=<SoftplusBackward0>)
# states tensor([-19.2069])
# mean_actions tensor([15.2735, 13.8019], grad_fn=<ViewBackward0>)
# std_actions tensor([0.0072, 0.7651], grad_fn=<SoftplusBackward0>)
# states tensor([-19.1800])
# mean_actions tensor([15.2957, 13.8687], grad_fn=<ViewBackward0>)
# std_actions tensor([0.0071, 0.7726], grad_fn=<SoftplusBackward0>)
# states tensor([-19.0849])
# mean_actions tensor([15.2589, 13.8772], grad_fn=<ViewBackward0>)
# std_actions tensor([0.0071, 0.7792], grad_fn=<SoftplusBackward0>)
# states tensor([-20.5210])
# mean_actions tensor([16.4456, 14.9987], grad_fn=<ViewBackward0>)
# std_actions tensor([0.0047, 0.7900], grad_fn=<SoftplusBackward0>)
# states tensor([-19.2442])
# mean_actions tensor([15.4540, 14.1270], grad_fn=<ViewBackward0>)
# std_actions tensor([0.0065, 0.7917], grad_fn=<SoftplusBackward0>)
# states tensor([-19.0883])
# mean_actions tensor([15.3574, 14.0691], grad_fn=<ViewBackward0>)
# std_actions tensor([0.0066, 0.7961], grad_fn=<SoftplusBackward0>)
# states tensor([-19.8929])
# mean_actions tensor([16.0322, 14.7165], grad_fn=<ViewBackward0>)
# std_actions tensor([0.0053, 0.8043], grad_fn=<SoftplusBackward0>)
# states tensor([-19.1062])
# mean_actions tensor([15.4210, 14.1797], grad_fn=<ViewBackward0>)
# std_actions tensor([0.0064, 0.8050], grad_fn=<SoftplusBackward0>)
# states tensor([-19.4001])
# mean_actions tensor([15.6799, 14.4405], grad_fn=<ViewBackward0>)
# std_actions tensor([0.0058, 0.8102], grad_fn=<SoftplusBackward0>)
# states tensor([-19.1062])
# mean_actions tensor([15.4611, 14.2588], grad_fn=<ViewBackward0>)
# std_actions tensor([0.0062, 0.8122], grad_fn=<SoftplusBackward0>)
# states tensor([-19.3938])
# mean_actions tensor([15.7114, 14.5082], grad_fn=<ViewBackward0>)
# std_actions tensor([0.0057, 0.8168], grad_fn=<SoftplusBackward0>)
# states tensor([-19.0849])
# mean_actions tensor([15.4763, 14.3071], grad_fn=<ViewBackward0>)
# std_actions tensor([0.0062, 0.8180], grad_fn=<SoftplusBackward0>)
# states tensor([-19.3703])
# mean_actions tensor([15.7221, 14.5494], grad_fn=<ViewBackward0>)
# std_actions tensor([0.0056, 0.8221], grad_fn=<SoftplusBackward0>)
# states tensor([-19.7683])
# mean_actions tensor([16.0592, 14.8736], grad_fn=<ViewBackward0>)
# std_actions tensor([0.0050, 0.8271], grad_fn=<SoftplusBackward0>)
# states tensor([-19.3354])
# mean_actions tensor([15.7182, 14.5703], grad_fn=<ViewBackward0>)
# std_actions tensor([0.0056, 0.8265], grad_fn=<SoftplusBackward0>)
# states tensor([-19.0904])
# mean_actions tensor([15.5290, 14.4057], grad_fn=<ViewBackward0>)
# std_actions tensor([0.0060, 0.8269], grad_fn=<SoftplusBackward0>)
# states tensor([-19.8929])
# mean_actions tensor([16.1933, 15.0297], grad_fn=<ViewBackward0>)
# std_actions tensor([0.0048, 0.8342], grad_fn=<SoftplusBackward0>)
# states tensor([-27.7981])
# mean_actions tensor([22.6525, 21.0254], grad_fn=<ViewBackward0>)
# std_actions tensor([5.5314e-04, 8.8419e-01], grad_fn=<SoftplusBackward0>)
# states tensor([-19.1170])
# mean_actions tensor([15.5761, 14.4743], grad_fn=<ViewBackward0>)
# std_actions tensor([0.0058, 0.8319], grad_fn=<SoftplusBackward0>)
# states tensor([-19.1090])
# mean_actions tensor([15.5765, 14.4815], grad_fn=<ViewBackward0>)
# std_actions tensor([0.0058, 0.8332], grad_fn=<SoftplusBackward0>)
# states tensor([-19.4437])
# mean_actions tensor([15.8564, 14.7470], grad_fn=<ViewBackward0>)
# std_actions tensor([0.0053, 0.8368], grad_fn=<SoftplusBackward0>)
# states tensor([-19.1416])
# mean_actions tensor([15.6150, 14.5287], grad_fn=<ViewBackward0>)
# std_actions tensor([0.0057, 0.8357], grad_fn=<SoftplusBackward0>)
# states tensor([-19.2578])
# mean_actions tensor([15.7151, 14.6265], grad_fn=<ViewBackward0>)
# std_actions tensor([0.0055, 0.8375], grad_fn=<SoftplusBackward0>)
# states tensor([-19.4676])
# mean_actions tensor([15.8914, 14.7946], grad_fn=<ViewBackward0>)
# std_actions tensor([0.0052, 0.8400], grad_fn=<SoftplusBackward0>)
# states tensor([-19.2199])
# mean_actions tensor([15.6928, 14.6143], grad_fn=<ViewBackward0>)
# std_actions tensor([0.0056, 0.8389], grad_fn=<SoftplusBackward0>)
# states tensor([-19.3354])
# mean_actions tensor([15.7910, 14.7092], grad_fn=<ViewBackward0>)
# std_actions tensor([0.0054, 0.8405], grad_fn=<SoftplusBackward0>)
# states tensor([-19.1696])
# mean_actions tensor([15.6586, 14.5895], grad_fn=<ViewBackward0>)
# std_actions tensor([0.0056, 0.8399], grad_fn=<SoftplusBackward0>)
# states tensor([-19.1416])
# mean_actions tensor([15.6387, 14.5739], grad_fn=<ViewBackward0>)
# std_actions tensor([0.0056, 0.8403], grad_fn=<SoftplusBackward0>)
# states tensor([-19.8929])
# mean_actions tensor([16.2569, 15.1511], grad_fn=<ViewBackward0>)
# std_actions tensor([0.0046, 0.8464], grad_fn=<SoftplusBackward0>)
# states tensor([-19.1139])
# mean_actions tensor([15.6211, 14.5626], grad_fn=<ViewBackward0>)
# std_actions tensor([0.0057, 0.8410], grad_fn=<SoftplusBackward0>)
# states tensor([-20.5210])
# mean_actions tensor([16.7761, 15.6391], grad_fn=<ViewBackward0>)
# std_actions tensor([0.0038, 0.8516], grad_fn=<SoftplusBackward0>)
# states tensor([-19.1416])
# mean_actions tensor([15.6480, 14.5916], grad_fn=<ViewBackward0>)
# std_actions tensor([0.0056, 0.8420], grad_fn=<SoftplusBackward0>)
# states tensor([-19.0679])
# mean_actions tensor([15.5893, 14.5389], grad_fn=<ViewBackward0>)
# std_actions tensor([0.0057, 0.8418], grad_fn=<SoftplusBackward0>)
# states tensor([0.])
# mean_actions tensor([0.0347, 0.3985], grad_fn=<ViewBackward0>)
# std_actions tensor([0.5076, 0.6354], grad_fn=<SoftplusBackward0>)
# states tensor([-27.7981])
# mean_actions tensor([22.8029, 21.1936], grad_fn=<ViewBackward0>)
# std_actions tensor([5.8291e-04, 8.9712e-01], grad_fn=<SoftplusBackward0>)
# states tensor([-23.2362])
# mean_actions tensor([19.1017, 17.7123], grad_fn=<ViewBackward0>)
# std_actions tensor([0.0022, 0.8627], grad_fn=<SoftplusBackward0>)
# states tensor([-19.1043])
# mean_actions tensor([15.7344, 14.5586], grad_fn=<ViewBackward0>)
# std_actions tensor([0.0069, 0.8326], grad_fn=<SoftplusBackward0>)
# states tensor([-19.1516])
# mean_actions tensor([15.8042, 14.5916], grad_fn=<ViewBackward0>)
# std_actions tensor([0.0072, 0.8303], grad_fn=<SoftplusBackward0>)
# states tensor([-19.8929])
# mean_actions tensor([16.4457, 15.1535], grad_fn=<ViewBackward0>)
# std_actions tensor([0.0063, 0.8330], grad_fn=<SoftplusBackward0>)
# states tensor([-19.2442])
# mean_actions tensor([15.9336, 14.6569], grad_fn=<ViewBackward0>)
# std_actions tensor([0.0078, 0.8264], grad_fn=<SoftplusBackward0>)
# states tensor([-19.1170])
# mean_actions tensor([15.8508, 14.5576], grad_fn=<ViewBackward0>)
# std_actions tensor([0.0084, 0.8238], grad_fn=<SoftplusBackward0>)
# states tensor([-19.2442])
# mean_actions tensor([15.9768, 14.6525], grad_fn=<ViewBackward0>)
# std_actions tensor([0.0084, 0.8229], grad_fn=<SoftplusBackward0>)
# states tensor([-19.5918])
# mean_actions tensor([16.2842, 14.9156], grad_fn=<ViewBackward0>)
# std_actions tensor([0.0080, 0.8235], grad_fn=<SoftplusBackward0>)
# states tensor([-19.0691])
# mean_actions tensor([15.8665, 14.5151], grad_fn=<ViewBackward0>)
# std_actions tensor([0.0094, 0.8191], grad_fn=<SoftplusBackward0>)
# states tensor([-19.1416])
# mean_actions tensor([15.9418, 14.5688], grad_fn=<ViewBackward0>)
# std_actions tensor([0.0095, 0.8184], grad_fn=<SoftplusBackward0>)
# states tensor([-19.1654])
# mean_actions tensor([15.9751, 14.5855], grad_fn=<ViewBackward0>)
# std_actions tensor([0.0096, 0.8175], grad_fn=<SoftplusBackward0>)
# states tensor([-19.1104])
# mean_actions tensor([15.9415, 14.5423], grad_fn=<ViewBackward0>)
# std_actions tensor([0.0100, 0.8162], grad_fn=<SoftplusBackward0>)
# states tensor([-19.8929])
# mean_actions tensor([16.6049, 15.1378], grad_fn=<ViewBackward0>)
# std_actions tensor([0.0084, 0.8195], grad_fn=<SoftplusBackward0>)
# states tensor([-19.6794])
# mean_actions tensor([16.4402, 14.9727], grad_fn=<ViewBackward0>)
# std_actions tensor([0.0090, 0.8160], grad_fn=<SoftplusBackward0>)
# states tensor([-27.7981])
# mean_actions tensor([23.2312, 21.1522], grad_fn=<ViewBackward0>)
# std_actions tensor([0.0013, 0.8585], grad_fn=<SoftplusBackward0>)
# states tensor([-19.0991])
# mean_actions tensor([15.9785, 14.5263], grad_fn=<ViewBackward0>)
# std_actions tensor([0.0106, 0.8085], grad_fn=<SoftplusBackward0>)
# states tensor([-19.5918])
# mean_actions tensor([16.3994, 14.9004], grad_fn=<ViewBackward0>)
# std_actions tensor([0.0095, 0.8095], grad_fn=<SoftplusBackward0>)
# states tensor([-19.1062])
# mean_actions tensor([16.0024, 14.5286], grad_fn=<ViewBackward0>)
# std_actions tensor([0.0108, 0.8052], grad_fn=<SoftplusBackward0>)
# states tensor([-19.1732])
# mean_actions tensor([16.0661, 14.5784], grad_fn=<ViewBackward0>)
# std_actions tensor([0.0107, 0.8042], grad_fn=<SoftplusBackward0>)
# states tensor([-19.0679])
# mean_actions tensor([15.9850, 14.4969], grad_fn=<ViewBackward0>)
# std_actions tensor([0.0111, 0.8023], grad_fn=<SoftplusBackward0>)
# states tensor([-19.0691])
# mean_actions tensor([15.9922, 14.4968], grad_fn=<ViewBackward0>)
# std_actions tensor([0.0112, 0.8012], grad_fn=<SoftplusBackward0>)
# states tensor([-19.1129])
# mean_actions tensor([16.0344, 14.5292], grad_fn=<ViewBackward0>)
# std_actions tensor([0.0111, 0.8004], grad_fn=<SoftplusBackward0>)
# states tensor([-19.2940])
# mean_actions tensor([16.1912, 14.6663], grad_fn=<ViewBackward0>)
# std_actions tensor([0.0107, 0.8003], grad_fn=<SoftplusBackward0>)
# states tensor([-19.1139])
# mean_actions tensor([16.0460, 14.5277], grad_fn=<ViewBackward0>)
# std_actions tensor([0.0113, 0.7979], grad_fn=<SoftplusBackward0>)
# states tensor([-19.3938])
# mean_actions tensor([16.2854, 14.7397], grad_fn=<ViewBackward0>)
# std_actions tensor([0.0106, 0.7978], grad_fn=<SoftplusBackward0>)
# states tensor([-19.1071])
# mean_actions tensor([16.0498, 14.5201], grad_fn=<ViewBackward0>)
# std_actions tensor([0.0114, 0.7952], grad_fn=<SoftplusBackward0>)
# states tensor([-19.0849])
# mean_actions tensor([16.0352, 14.5022], grad_fn=<ViewBackward0>)
# std_actions tensor([0.0115, 0.7940], grad_fn=<SoftplusBackward0>)
# states tensor([-19.1170])
# mean_actions tensor([16.0658, 14.5257], grad_fn=<ViewBackward0>)
# std_actions tensor([0.0114, 0.7932], grad_fn=<SoftplusBackward0>)
# states tensor([-19.7683])
# mean_actions tensor([16.6152, 15.0211], grad_fn=<ViewBackward0>)
# std_actions tensor([0.0098, 0.7953], grad_fn=<SoftplusBackward0>)
# states tensor([-19.1138])
# mean_actions tensor([16.0694, 14.5217], grad_fn=<ViewBackward0>)
# std_actions tensor([0.0115, 0.7915], grad_fn=<SoftplusBackward0>)
# states tensor([-19.1043])
# mean_actions tensor([16.0641, 14.5139], grad_fn=<ViewBackward0>)
# std_actions tensor([0.0115, 0.7907], grad_fn=<SoftplusBackward0>)
# states tensor([-19.1416])
# mean_actions tensor([16.0978, 14.5417], grad_fn=<ViewBackward0>)
# std_actions tensor([0.0114, 0.7902], grad_fn=<SoftplusBackward0>)
# states tensor([-19.1416])
# mean_actions tensor([16.1000, 14.5411], grad_fn=<ViewBackward0>)
# std_actions tensor([0.0115, 0.7896], grad_fn=<SoftplusBackward0>)
# states tensor([-19.0849])
# mean_actions tensor([16.0544, 14.4974], grad_fn=<ViewBackward0>)
# std_actions tensor([0.0116, 0.7888], grad_fn=<SoftplusBackward0>)
# states tensor([-23.2362])
# mean_actions tensor([19.5411, 17.6567], grad_fn=<ViewBackward0>)
# std_actions tensor([0.0044, 0.8053], grad_fn=<SoftplusBackward0>)
# states tensor([-19.1159])
# mean_actions tensor([16.0838, 14.5202], grad_fn=<ViewBackward0>)
# std_actions tensor([0.0116, 0.7880], grad_fn=<SoftplusBackward0>)
# states tensor([-19.2129])
# mean_actions tensor([16.1665, 14.5937], grad_fn=<ViewBackward0>)
# std_actions tensor([0.0113, 0.7881], grad_fn=<SoftplusBackward0>)
# states tensor([-19.1696])
# mean_actions tensor([16.1316, 14.5604], grad_fn=<ViewBackward0>)
# std_actions tensor([0.0115, 0.7875], grad_fn=<SoftplusBackward0>)
# states tensor([-19.0679])
# mean_actions tensor([16.0473, 14.4827], grad_fn=<ViewBackward0>)
# std_actions tensor([0.0118, 0.7868], grad_fn=<SoftplusBackward0>)
# states tensor([-19.1732])
# mean_actions tensor([16.1368, 14.5627], grad_fn=<ViewBackward0>)
# std_actions tensor([0.0115, 0.7869], grad_fn=<SoftplusBackward0>)
# states tensor([-19.1423])
# mean_actions tensor([16.1118, 14.5388], grad_fn=<ViewBackward0>)
# std_actions tensor([0.0116, 0.7866], grad_fn=<SoftplusBackward0>)
# states tensor([-20.0591])
# mean_actions tensor([16.8821, 15.2369], grad_fn=<ViewBackward0>)
# std_actions tensor([0.0093, 0.7900], grad_fn=<SoftplusBackward0>)
# states tensor([-20.5210])
# mean_actions tensor([17.2704, 15.5887], grad_fn=<ViewBackward0>)
# std_actions tensor([0.0084, 0.7913], grad_fn=<SoftplusBackward0>)
# states tensor([-19.1542])
# mean_actions tensor([16.1242, 14.5474], grad_fn=<ViewBackward0>)
# std_actions tensor([0.0116, 0.7860], grad_fn=<SoftplusBackward0>)
# states tensor([-19.1516])
# mean_actions tensor([16.1226, 14.5452], grad_fn=<ViewBackward0>)
# std_actions tensor([0.0116, 0.7858], grad_fn=<SoftplusBackward0>)
# states tensor([-19.1519])
# mean_actions tensor([16.1234, 14.5453], grad_fn=<ViewBackward0>)
# std_actions tensor([0.0116, 0.7856], grad_fn=<SoftplusBackward0>)
# states tensor([-19.2080])
# mean_actions tensor([16.1710, 14.5879], grad_fn=<ViewBackward0>)
# std_actions tensor([0.0114, 0.7857], grad_fn=<SoftplusBackward0>)
# states tensor([-19.3572])
# mean_actions tensor([16.2967, 14.7014], grad_fn=<ViewBackward0>)
# std_actions tensor([0.0110, 0.7863], grad_fn=<SoftplusBackward0>)
# states tensor([-19.1623])
# mean_actions tensor([16.1335, 14.5529], grad_fn=<ViewBackward0>)
# std_actions tensor([0.0116, 0.7853], grad_fn=<SoftplusBackward0>)
# states tensor([-19.4103])
# mean_actions tensor([16.3420, 14.7416], grad_fn=<ViewBackward0>)
# std_actions tensor([0.0109, 0.7863], grad_fn=<SoftplusBackward0>)
# states tensor([-21.0473])
# mean_actions tensor([17.7167, 15.9883], grad_fn=<ViewBackward0>)
# std_actions tensor([0.0074, 0.7921], grad_fn=<SoftplusBackward0>)
# states tensor([-19.1889])
# mean_actions tensor([16.1569, 14.5729], grad_fn=<ViewBackward0>)
# std_actions tensor([0.0115, 0.7852], grad_fn=<SoftplusBackward0>)
# states tensor([-19.8929])
# mean_actions tensor([16.7482, 15.1089], grad_fn=<ViewBackward0>)
# std_actions tensor([0.0098, 0.7880], grad_fn=<SoftplusBackward0>)
# states tensor([-19.6794])
# mean_actions tensor([16.5692, 14.9462], grad_fn=<ViewBackward0>)
# std_actions tensor([0.0103, 0.7871], grad_fn=<SoftplusBackward0>)
# states tensor([-19.1654])
# mean_actions tensor([16.1378, 14.5548], grad_fn=<ViewBackward0>)
# std_actions tensor([0.0116, 0.7849], grad_fn=<SoftplusBackward0>)
# states tensor([-21.7770])
# mean_actions tensor([18.3315, 16.5428], grad_fn=<ViewBackward0>)
# std_actions tensor([0.0063, 0.7947], grad_fn=<SoftplusBackward0>)
# states tensor([-19.1423])
# mean_actions tensor([16.1188, 14.5371], grad_fn=<ViewBackward0>)
# std_actions tensor([0.0116, 0.7847], grad_fn=<SoftplusBackward0>)
# states tensor([-19.6282])
# mean_actions tensor([16.5270, 14.9070], grad_fn=<ViewBackward0>)
# std_actions tensor([0.0104, 0.7867], grad_fn=<SoftplusBackward0>)
# states tensor([-23.2362])
# mean_actions tensor([19.5588, 17.6524], grad_fn=<ViewBackward0>)
# std_actions tensor([0.0044, 0.8004], grad_fn=<SoftplusBackward0>)
# states tensor([-19.1139])
# mean_actions tensor([16.0954, 14.5154], grad_fn=<ViewBackward0>)
# std_actions tensor([0.0117, 0.7844], grad_fn=<SoftplusBackward0>)
# states tensor([-19.1109])
# mean_actions tensor([16.0930, 14.5131], grad_fn=<ViewBackward0>)
# std_actions tensor([0.0117, 0.7844], grad_fn=<SoftplusBackward0>)
# states tensor([0.])
# mean_actions tensor([0.5610, 0.2969], grad_fn=<ViewBackward0>)
# std_actions tensor([0.6362, 0.6153], grad_fn=<SoftplusBackward0>)
# states tensor([-20.0591])
# mean_actions tensor([16.8673, 15.2415], grad_fn=<ViewBackward0>)
# std_actions tensor([0.0094, 0.7806], grad_fn=<SoftplusBackward0>)
# states tensor([-19.7683])
# mean_actions tensor([16.6041, 15.0255], grad_fn=<ViewBackward0>)
# std_actions tensor([0.0100, 0.7732], grad_fn=<SoftplusBackward0>)
# states tensor([-19.1883])
# mean_actions tensor([16.1012, 14.5885], grad_fn=<ViewBackward0>)
# std_actions tensor([0.0115, 0.7655], grad_fn=<SoftplusBackward0>)
# states tensor([-19.1732])
# mean_actions tensor([16.0733, 14.5814], grad_fn=<ViewBackward0>)
# std_actions tensor([0.0115, 0.7604], grad_fn=<SoftplusBackward0>)
# states tensor([-19.1129])
# mean_actions tensor([16.0091, 14.5393], grad_fn=<ViewBackward0>)
# std_actions tensor([0.0117, 0.7557], grad_fn=<SoftplusBackward0>)
# states tensor([-19.0883])
# mean_actions tensor([15.9763, 14.5241], grad_fn=<ViewBackward0>)
# std_actions tensor([0.0117, 0.7517], grad_fn=<SoftplusBackward0>)
# states tensor([-19.1138])
# mean_actions tensor([15.9866, 14.5465], grad_fn=<ViewBackward0>)
# std_actions tensor([0.0117, 0.7482], grad_fn=<SoftplusBackward0>)
# states tensor([-20.2676])
# mean_actions tensor([16.9409, 15.4278], grad_fn=<ViewBackward0>)
# std_actions tensor([0.0089, 0.7482], grad_fn=<SoftplusBackward0>)
# states tensor([-19.1542])
# mean_actions tensor([16.0020, 14.5823], grad_fn=<ViewBackward0>)
# std_actions tensor([0.0115, 0.7425], grad_fn=<SoftplusBackward0>)
# states tensor([-19.3207])
# mean_actions tensor([16.1331, 14.7111], grad_fn=<ViewBackward0>)
# std_actions tensor([0.0111, 0.7404], grad_fn=<SoftplusBackward0>)
# states tensor([-23.2362])
# mean_actions tensor([19.3919, 17.6974], grad_fn=<ViewBackward0>)
# std_actions tensor([0.0044, 0.7455], grad_fn=<SoftplusBackward0>)
# states tensor([-19.2069])
# mean_actions tensor([16.0246, 14.6280], grad_fn=<ViewBackward0>)
# std_actions tensor([0.0114, 0.7359], grad_fn=<SoftplusBackward0>)
# states tensor([-19.1090])
# mean_actions tensor([15.9371, 14.5550], grad_fn=<ViewBackward0>)
# std_actions tensor([0.0117, 0.7338], grad_fn=<SoftplusBackward0>)
# states tensor([-19.3703])
# mean_actions tensor([16.1499, 14.7555], grad_fn=<ViewBackward0>)
# std_actions tensor([0.0110, 0.7328], grad_fn=<SoftplusBackward0>)
# states tensor([-19.1170])
# mean_actions tensor([15.9340, 14.5636], grad_fn=<ViewBackward0>)
# std_actions tensor([0.0116, 0.7308], grad_fn=<SoftplusBackward0>)
# states tensor([-19.6794])
# mean_actions tensor([16.3985, 14.9933], grad_fn=<ViewBackward0>)
# std_actions tensor([0.0102, 0.7308], grad_fn=<SoftplusBackward0>)
# states tensor([-19.1628])
# mean_actions tensor([15.9642, 14.6007], grad_fn=<ViewBackward0>)
# std_actions tensor([0.0115, 0.7284], grad_fn=<SoftplusBackward0>)
# states tensor([-19.6282])
# mean_actions tensor([16.3485, 14.9563], grad_fn=<ViewBackward0>)
# std_actions tensor([0.0103, 0.7284], grad_fn=<SoftplusBackward0>)
# states tensor([-23.2362])
# mean_actions tensor([19.3484, 17.7089], grad_fn=<ViewBackward0>)
# std_actions tensor([0.0044, 0.7319], grad_fn=<SoftplusBackward0>)
# states tensor([-19.4308])
# mean_actions tensor([16.1782, 14.8074], grad_fn=<ViewBackward0>)
# std_actions tensor([0.0108, 0.7261], grad_fn=<SoftplusBackward0>)
# states tensor([-19.3354])
# mean_actions tensor([16.0962, 14.7353], grad_fn=<ViewBackward0>)
# std_actions tensor([0.0110, 0.7252], grad_fn=<SoftplusBackward0>)
# states tensor([-19.1732])
# mean_actions tensor([15.9589, 14.6123], grad_fn=<ViewBackward0>)
# std_actions tensor([0.0115, 0.7241], grad_fn=<SoftplusBackward0>)
# states tensor([-19.2015])
# mean_actions tensor([15.9804, 14.6344], grad_fn=<ViewBackward0>)
# std_actions tensor([0.0114, 0.7236], grad_fn=<SoftplusBackward0>)
# states tensor([-19.0991])
# mean_actions tensor([15.8934, 14.5568], grad_fn=<ViewBackward0>)
# std_actions tensor([0.0117, 0.7228], grad_fn=<SoftplusBackward0>)
# states tensor([-21.0473])
# mean_actions tensor([17.5125, 16.0431], grad_fn=<ViewBackward0>)
# std_actions tensor([0.0074, 0.7249], grad_fn=<SoftplusBackward0>)
# states tensor([-19.1090])
# mean_actions tensor([15.8985, 14.5652], grad_fn=<ViewBackward0>)
# std_actions tensor([0.0116, 0.7219], grad_fn=<SoftplusBackward0>)
# states tensor([-19.2646])
# mean_actions tensor([16.0266, 14.6841], grad_fn=<ViewBackward0>)
# std_actions tensor([0.0112, 0.7218], grad_fn=<SoftplusBackward0>)
# states tensor([-19.1071])
# mean_actions tensor([15.8944, 14.5644], grad_fn=<ViewBackward0>)
# std_actions tensor([0.0116, 0.7211], grad_fn=<SoftplusBackward0>)
# states tensor([-19.8929])
# mean_actions tensor([16.5471, 15.1638], grad_fn=<ViewBackward0>)
# std_actions tensor([0.0097, 0.7222], grad_fn=<SoftplusBackward0>)
# states tensor([-19.1090])
# mean_actions tensor([15.8940, 14.5664], grad_fn=<ViewBackward0>)
# std_actions tensor([0.0116, 0.7205], grad_fn=<SoftplusBackward0>)
# states tensor([-19.1062])
# mean_actions tensor([15.8907, 14.5644], grad_fn=<ViewBackward0>)
# std_actions tensor([0.0116, 0.7202], grad_fn=<SoftplusBackward0>)
# states tensor([-19.1139])
# mean_actions tensor([15.8964, 14.5706], grad_fn=<ViewBackward0>)
# std_actions tensor([0.0116, 0.7200], grad_fn=<SoftplusBackward0>)
# states tensor([-19.4308])
# mean_actions tensor([16.1593, 14.8123], grad_fn=<ViewBackward0>)
# std_actions tensor([0.0108, 0.7203], grad_fn=<SoftplusBackward0>)
# states tensor([-19.1883])
# mean_actions tensor([15.9569, 14.6276], grad_fn=<ViewBackward0>)
# std_actions tensor([0.0114, 0.7197], grad_fn=<SoftplusBackward0>)
# states tensor([-19.2832])
# mean_actions tensor([16.0352, 14.7001], grad_fn=<ViewBackward0>)
# std_actions tensor([0.0112, 0.7197], grad_fn=<SoftplusBackward0>)
# states tensor([-19.6794])
# mean_actions tensor([16.3643, 15.0023], grad_fn=<ViewBackward0>)
# std_actions tensor([0.0102, 0.7202], grad_fn=<SoftplusBackward0>)
# states tensor([-19.1043])
# mean_actions tensor([15.8855, 14.5640], grad_fn=<ViewBackward0>)
# std_actions tensor([0.0116, 0.7191], grad_fn=<SoftplusBackward0>)
# states tensor([-21.0473])
# mean_actions tensor([17.5004, 16.0462], grad_fn=<ViewBackward0>)
# std_actions tensor([0.0074, 0.7213], grad_fn=<SoftplusBackward0>)
# states tensor([-19.2804])
# mean_actions tensor([16.0312, 14.6985], grad_fn=<ViewBackward0>)
# std_actions tensor([0.0112, 0.7191], grad_fn=<SoftplusBackward0>)
# states tensor([-19.1416])
# mean_actions tensor([15.9154, 14.5927], grad_fn=<ViewBackward0>)
# std_actions tensor([0.0115, 0.7188], grad_fn=<SoftplusBackward0>)
# states tensor([-19.1425])
# mean_actions tensor([15.9158, 14.5934], grad_fn=<ViewBackward0>)
# std_actions tensor([0.0115, 0.7187], grad_fn=<SoftplusBackward0>)
# states tensor([-19.2940])
# mean_actions tensor([16.0415, 14.7090], grad_fn=<ViewBackward0>)
# std_actions tensor([0.0111, 0.7189], grad_fn=<SoftplusBackward0>)
# states tensor([-19.1829])
# mean_actions tensor([15.9488, 14.6244], grad_fn=<ViewBackward0>)
# std_actions tensor([0.0114, 0.7186], grad_fn=<SoftplusBackward0>)
# states tensor([-19.1519])
# mean_actions tensor([15.9229, 14.6008], grad_fn=<ViewBackward0>)
# std_actions tensor([0.0115, 0.7185], grad_fn=<SoftplusBackward0>)
# states tensor([-19.1628])
# mean_actions tensor([15.9317, 14.6092], grad_fn=<ViewBackward0>)
# std_actions tensor([0.0115, 0.7184], grad_fn=<SoftplusBackward0>)
# states tensor([-19.6282])
# mean_actions tensor([16.3186, 14.9641], grad_fn=<ViewBackward0>)
# std_actions tensor([0.0103, 0.7192], grad_fn=<SoftplusBackward0>)
# states tensor([-19.0904])
# mean_actions tensor([15.8712, 14.5541], grad_fn=<ViewBackward0>)
# std_actions tensor([0.0117, 0.7182], grad_fn=<SoftplusBackward0>)
# states tensor([-19.7683])
# mean_actions tensor([16.4348, 15.0710], grad_fn=<ViewBackward0>)
# std_actions tensor([0.0100, 0.7193], grad_fn=<SoftplusBackward0>)
# states tensor([-19.8929])
# mean_actions tensor([16.5382, 15.1661], grad_fn=<ViewBackward0>)
# std_actions tensor([0.0097, 0.7195], grad_fn=<SoftplusBackward0>)
# states tensor([-19.1800])
# mean_actions tensor([15.9452, 14.6225], grad_fn=<ViewBackward0>)
# std_actions tensor([0.0114, 0.7182], grad_fn=<SoftplusBackward0>)
# states tensor([-19.4308])
# mean_actions tensor([16.1538, 14.8138], grad_fn=<ViewBackward0>)
# std_actions tensor([0.0108, 0.7186], grad_fn=<SoftplusBackward0>)
# states tensor([-21.7770])
# mean_actions tensor([18.1036, 16.6039], grad_fn=<ViewBackward0>)
# std_actions tensor([0.0062, 0.7209], grad_fn=<SoftplusBackward0>)
# states tensor([-20.5210])
# mean_actions tensor([17.0597, 15.6455], grad_fn=<ViewBackward0>)
# std_actions tensor([0.0083, 0.7198], grad_fn=<SoftplusBackward0>)
# states tensor([-20.2676])
# mean_actions tensor([16.8490, 15.4521], grad_fn=<ViewBackward0>)
# std_actions tensor([0.0089, 0.7196], grad_fn=<SoftplusBackward0>)
# states tensor([-19.0691])
# mean_actions tensor([15.8526, 14.5380], grad_fn=<ViewBackward0>)
# std_actions tensor([0.0117, 0.7179], grad_fn=<SoftplusBackward0>)
# states tensor([-19.4001])
# mean_actions tensor([16.1278, 14.7905], grad_fn=<ViewBackward0>)
# std_actions tensor([0.0109, 0.7185], grad_fn=<SoftplusBackward0>)
# states tensor([-19.2006])
# mean_actions tensor([15.9619, 14.6384], grad_fn=<ViewBackward0>)
# std_actions tensor([0.0114, 0.7181], grad_fn=<SoftplusBackward0>)
# states tensor([-19.6794])
# mean_actions tensor([16.3599, 15.0034], grad_fn=<ViewBackward0>)
# std_actions tensor([0.0102, 0.7189], grad_fn=<SoftplusBackward0>)
# states tensor([-19.3938])
# mean_actions tensor([16.1224, 14.7857], grad_fn=<ViewBackward0>)
# std_actions tensor([0.0109, 0.7184], grad_fn=<SoftplusBackward0>)
# states tensor([-19.1654])
# mean_actions tensor([15.9324, 14.6115], grad_fn=<ViewBackward0>)
# std_actions tensor([0.0115, 0.7180], grad_fn=<SoftplusBackward0>)
# states tensor([-19.2979])
# mean_actions tensor([16.0426, 14.7126], grad_fn=<ViewBackward0>)
# std_actions tensor([0.0111, 0.7182], grad_fn=<SoftplusBackward0>)
# states tensor([-19.2069])
# mean_actions tensor([15.9669, 14.6432], grad_fn=<ViewBackward0>)
# std_actions tensor([0.0114, 0.7180], grad_fn=<SoftplusBackward0>)
# states tensor([-19.1732])
# mean_actions tensor([15.9388, 14.6176], grad_fn=<ViewBackward0>)
# std_actions tensor([0.0115, 0.7180], grad_fn=<SoftplusBackward0>)
# states tensor([-19.8929])
# mean_actions tensor([16.5372, 15.1664], grad_fn=<ViewBackward0>)
# std_actions tensor([0.0097, 0.7192], grad_fn=<SoftplusBackward0>)
# states tensor([-19.1654])
# mean_actions tensor([15.9322, 14.6116], grad_fn=<ViewBackward0>)
# std_actions tensor([0.0115, 0.7179], grad_fn=<SoftplusBackward0>)
# states tensor([-19.1170])
# mean_actions tensor([15.8920, 14.5747], grad_fn=<ViewBackward0>)
# std_actions tensor([0.0116, 0.7179], grad_fn=<SoftplusBackward0>)
# states tensor([-19.6794])
# mean_actions tensor([16.3596, 15.0035], grad_fn=<ViewBackward0>)
# std_actions tensor([0.0102, 0.7188], grad_fn=<SoftplusBackward0>)
# states tensor([-19.2646])
# mean_actions tensor([16.0147, 14.6872], grad_fn=<ViewBackward0>)
# std_actions tensor([0.0112, 0.7181], grad_fn=<SoftplusBackward0>)
# states tensor([-23.2362])
# mean_actions tensor([19.3153, 17.7175], grad_fn=<ViewBackward0>)
# std_actions tensor([0.0044, 0.7218], grad_fn=<SoftplusBackward0>)
# states tensor([-19.1800])
# mean_actions tensor([15.9443, 14.6227], grad_fn=<ViewBackward0>)
# std_actions tensor([0.0114, 0.7179], grad_fn=<SoftplusBackward0>)
# states tensor([-19.1170])
# mean_actions tensor([15.8919, 14.5747], grad_fn=<ViewBackward0>)
# std_actions tensor([0.0116, 0.7178], grad_fn=<SoftplusBackward0>)
# states tensor([-19.1416])
# mean_actions tensor([15.9124, 14.5935], grad_fn=<ViewBackward0>)
# std_actions tensor([0.0115, 0.7179], grad_fn=<SoftplusBackward0>)
# states tensor([-19.1062])
# mean_actions tensor([15.8829, 14.5665], grad_fn=<ViewBackward0>)
# std_actions tensor([0.0116, 0.7178], grad_fn=<SoftplusBackward0>)
# states tensor([-19.1942])
# mean_actions tensor([15.9561, 14.6336], grad_fn=<ViewBackward0>)
# std_actions tensor([0.0114, 0.7180], grad_fn=<SoftplusBackward0>)
# states tensor([-19.0904])
# mean_actions tensor([15.8698, 14.5545], grad_fn=<ViewBackward0>)
# std_actions tensor([0.0117, 0.7178], grad_fn=<SoftplusBackward0>)
# states tensor([-27.7981])
# mean_actions tensor([23.1058, 21.1960], grad_fn=<ViewBackward0>)
# std_actions tensor([0.0015, 0.7252], grad_fn=<SoftplusBackward0>)
# states tensor([0.])
# mean_actions tensor([0.3909, 0.3483], grad_fn=<ViewBackward0>)
# std_actions tensor([0.6332, 0.5348], grad_fn=<SoftplusBackward0>)
# states tensor([-21.7770])
# mean_actions tensor([18.1072, 16.5743], grad_fn=<ViewBackward0>)
# std_actions tensor([0.0058, 0.7041], grad_fn=<SoftplusBackward0>)
# states tensor([-19.4001])
# mean_actions tensor([16.1347, 14.7394], grad_fn=<ViewBackward0>)
# std_actions tensor([0.0096, 0.6903], grad_fn=<SoftplusBackward0>)
# states tensor([-19.1425])
# mean_actions tensor([15.9233, 14.5214], grad_fn=<ViewBackward0>)
# std_actions tensor([0.0097, 0.6786], grad_fn=<SoftplusBackward0>)
# states tensor([-19.3207])
# mean_actions tensor([16.0743, 14.6364], grad_fn=<ViewBackward0>)
# std_actions tensor([0.0088, 0.6680], grad_fn=<SoftplusBackward0>)
# states tensor([-19.1696])
# mean_actions tensor([15.9508, 14.5035], grad_fn=<ViewBackward0>)
# std_actions tensor([0.0088, 0.6588], grad_fn=<SoftplusBackward0>)
# states tensor([-19.1623])
# mean_actions tensor([15.9467, 14.4813], grad_fn=<ViewBackward0>)
# std_actions tensor([0.0084, 0.6505], grad_fn=<SoftplusBackward0>)
# states tensor([-19.2006])
# mean_actions tensor([15.9804, 14.4952], grad_fn=<ViewBackward0>)
# std_actions tensor([0.0081, 0.6429], grad_fn=<SoftplusBackward0>)
# states tensor([-19.1623])
# mean_actions tensor([15.9500, 14.4524], grad_fn=<ViewBackward0>)
# std_actions tensor([0.0079, 0.6362], grad_fn=<SoftplusBackward0>)
# states tensor([-19.7683])
# mean_actions tensor([16.4562, 14.8972], grad_fn=<ViewBackward0>)
# std_actions tensor([0.0066, 0.6287], grad_fn=<SoftplusBackward0>)
# states tensor([-19.0904])
# mean_actions tensor([15.8927, 14.3745], grad_fn=<ViewBackward0>)
# std_actions tensor([0.0076, 0.6250], grad_fn=<SoftplusBackward0>)
# states tensor([-19.1129])
# mean_actions tensor([15.9125, 14.3812], grad_fn=<ViewBackward0>)
# std_actions tensor([0.0074, 0.6201], grad_fn=<SoftplusBackward0>)
# states tensor([0.])
# mean_actions tensor([0.3170, 0.1635], grad_fn=<ViewBackward0>)
# std_actions tensor([0.5849, 0.5072], grad_fn=<SoftplusBackward0>)
# states tensor([-19.1062])
# mean_actions tensor([15.8662, 14.3948], grad_fn=<ViewBackward0>)
# std_actions tensor([0.0074, 0.6313], grad_fn=<SoftplusBackward0>)
# states tensor([-19.1696])
# mean_actions tensor([15.8816, 14.4675], grad_fn=<ViewBackward0>)
# std_actions tensor([0.0074, 0.6453], grad_fn=<SoftplusBackward0>)
# states tensor([-19.1423])
# mean_actions tensor([15.8258, 14.4688], grad_fn=<ViewBackward0>)
# std_actions tensor([0.0076, 0.6582], grad_fn=<SoftplusBackward0>)
# states tensor([-21.0473])
# mean_actions tensor([17.3694, 15.9322], grad_fn=<ViewBackward0>)
# std_actions tensor([0.0047, 0.6675], grad_fn=<SoftplusBackward0>)
# states tensor([-19.6282])
# mean_actions tensor([16.1705, 14.8743], grad_fn=<ViewBackward0>)
# std_actions tensor([0.0069, 0.6804], grad_fn=<SoftplusBackward0>)
# states tensor([-19.1889])
# mean_actions tensor([15.7845, 14.5567], grad_fn=<ViewBackward0>)
# std_actions tensor([0.0078, 0.6900], grad_fn=<SoftplusBackward0>)
# states tensor([-19.0849])
# mean_actions tensor([15.6777, 14.4915], grad_fn=<ViewBackward0>)
# std_actions tensor([0.0081, 0.6986], grad_fn=<SoftplusBackward0>)
# states tensor([-20.5210])
# mean_actions tensor([16.8386, 15.5961], grad_fn=<ViewBackward0>)
# std_actions tensor([0.0057, 0.7074], grad_fn=<SoftplusBackward0>)
# states tensor([-21.0473])
# mean_actions tensor([17.2565, 16.0064], grad_fn=<ViewBackward0>)
# std_actions tensor([0.0050, 0.7121], grad_fn=<SoftplusBackward0>)
# states tensor([-19.1654])
# mean_actions tensor([15.7031, 14.5801], grad_fn=<ViewBackward0>)
# std_actions tensor([0.0080, 0.7119], grad_fn=<SoftplusBackward0>)
# states tensor([-20.0591])
# mean_actions tensor([16.4300, 15.2657], grad_fn=<ViewBackward0>)
# std_actions tensor([0.0064, 0.7131], grad_fn=<SoftplusBackward0>)
# states tensor([-19.1138])
# mean_actions tensor([15.6478, 14.5507], grad_fn=<ViewBackward0>)
# std_actions tensor([0.0081, 0.7128], grad_fn=<SoftplusBackward0>)
# states tensor([-20.0591])
# mean_actions tensor([16.4178, 15.2749], grad_fn=<ViewBackward0>)
# std_actions tensor([0.0064, 0.7141], grad_fn=<SoftplusBackward0>)
# states tensor([-19.8929])
# mean_actions tensor([16.2764, 15.1522], grad_fn=<ViewBackward0>)
# std_actions tensor([0.0066, 0.7144], grad_fn=<SoftplusBackward0>)
# states tensor([-27.7981])
# mean_actions tensor([22.7492, 21.1803], grad_fn=<ViewBackward0>)
# std_actions tensor([0.0009, 0.7163], grad_fn=<SoftplusBackward0>)
# states tensor([-19.8929])
# mean_actions tensor([16.2675, 15.1589], grad_fn=<ViewBackward0>)
# std_actions tensor([0.0066, 0.7151], grad_fn=<SoftplusBackward0>)
# states tensor([-20.5210])
# mean_actions tensor([16.7782, 15.6408], grad_fn=<ViewBackward0>)
# std_actions tensor([0.0057, 0.7155], grad_fn=<SoftplusBackward0>)
# states tensor([-19.0855])
# mean_actions tensor([15.5987, 14.5489], grad_fn=<ViewBackward0>)
# std_actions tensor([0.0081, 0.7147], grad_fn=<SoftplusBackward0>)
# states tensor([-19.4676])
# mean_actions tensor([15.9088, 14.8424], grad_fn=<ViewBackward0>)
# std_actions tensor([0.0074, 0.7154], grad_fn=<SoftplusBackward0>)
# states tensor([-19.0991])
# mean_actions tensor([15.6042, 14.5635], grad_fn=<ViewBackward0>)
# std_actions tensor([0.0081, 0.7151], grad_fn=<SoftplusBackward0>)
# states tensor([-19.4308])
# mean_actions tensor([15.8735, 14.8183], grad_fn=<ViewBackward0>)
# std_actions tensor([0.0075, 0.7157], grad_fn=<SoftplusBackward0>)
# states tensor([-19.1516])
# mean_actions tensor([15.6427, 14.6070], grad_fn=<ViewBackward0>)
# std_actions tensor([0.0080, 0.7155], grad_fn=<SoftplusBackward0>)
# states tensor([-19.5356])
# mean_actions tensor([15.9552, 14.9013], grad_fn=<ViewBackward0>)
# std_actions tensor([0.0073, 0.7162], grad_fn=<SoftplusBackward0>)
# states tensor([-19.2578])
# mean_actions tensor([15.7259, 14.6908], grad_fn=<ViewBackward0>)
# std_actions tensor([0.0078, 0.7159], grad_fn=<SoftplusBackward0>)
# states tensor([-19.1159])
# mean_actions tensor([15.6081, 14.5838], grad_fn=<ViewBackward0>)
# std_actions tensor([0.0081, 0.7159], grad_fn=<SoftplusBackward0>)
# states tensor([-19.3938])
# mean_actions tensor([15.8342, 14.7968], grad_fn=<ViewBackward0>)
# std_actions tensor([0.0075, 0.7163], grad_fn=<SoftplusBackward0>)
# states tensor([-21.0473])
# mean_actions tensor([17.1858, 16.0600], grad_fn=<ViewBackward0>)
# std_actions tensor([0.0049, 0.7174], grad_fn=<SoftplusBackward0>)
# states tensor([-19.1416])
# mean_actions tensor([15.6253, 14.6063], grad_fn=<ViewBackward0>)
# std_actions tensor([0.0080, 0.7162], grad_fn=<SoftplusBackward0>)
# states tensor([-19.1416])
# mean_actions tensor([15.6242, 14.6071], grad_fn=<ViewBackward0>)
# std_actions tensor([0.0080, 0.7163], grad_fn=<SoftplusBackward0>)
# states tensor([-19.1516])
# mean_actions tensor([15.6315, 14.6155], grad_fn=<ViewBackward0>)
# std_actions tensor([0.0080, 0.7164], grad_fn=<SoftplusBackward0>)
# states tensor([-19.1732])
# mean_actions tensor([15.6484, 14.6326], grad_fn=<ViewBackward0>)
# std_actions tensor([0.0079, 0.7165], grad_fn=<SoftplusBackward0>)
# states tensor([-19.1425])
# mean_actions tensor([15.6224, 14.6097], grad_fn=<ViewBackward0>)
# std_actions tensor([0.0080, 0.7165], grad_fn=<SoftplusBackward0>)
# states tensor([-19.1732])
# mean_actions tensor([15.6469, 14.6337], grad_fn=<ViewBackward0>)
# std_actions tensor([0.0079, 0.7166], grad_fn=<SoftplusBackward0>)
# states tensor([-20.2676])
# mean_actions tensor([16.5416, 15.4696], grad_fn=<ViewBackward0>)
# std_actions tensor([0.0060, 0.7176], grad_fn=<SoftplusBackward0>)
# states tensor([-19.0679])
# mean_actions tensor([15.5595, 14.5542], grad_fn=<ViewBackward0>)
# std_actions tensor([0.0082, 0.7165], grad_fn=<SoftplusBackward0>)
# states tensor([0.])
# mean_actions tensor([0.1454, 0.3546], grad_fn=<ViewBackward0>)
# std_actions tensor([0.5947, 0.5323], grad_fn=<SoftplusBackward0>)
# states tensor([-19.2832])
# mean_actions tensor([15.7316, 14.6939], grad_fn=<ViewBackward0>)
# std_actions tensor([0.0078, 0.7287], grad_fn=<SoftplusBackward0>)
# states tensor([-19.2646])
# mean_actions tensor([15.7132, 14.6574], grad_fn=<ViewBackward0>)
# std_actions tensor([0.0078, 0.7395], grad_fn=<SoftplusBackward0>)
# states tensor([0.])
# mean_actions tensor([0.1383, 0.2887], grad_fn=<ViewBackward0>)
# std_actions tensor([0.6002, 0.5564], grad_fn=<SoftplusBackward0>)
# states tensor([-19.0855])
# mean_actions tensor([15.5498, 14.5139], grad_fn=<ViewBackward0>)
# std_actions tensor([0.0080, 0.7685], grad_fn=<SoftplusBackward0>)
# states tensor([0.])
# mean_actions tensor([0.1222, 0.3106], grad_fn=<ViewBackward0>)
# std_actions tensor([0.5976, 0.5823], grad_fn=<SoftplusBackward0>)
# states tensor([-19.0691])
# mean_actions tensor([15.4971, 14.5230], grad_fn=<ViewBackward0>)
# std_actions tensor([0.0075, 0.8032], grad_fn=<SoftplusBackward0>)
# states tensor([-19.1139])
# mean_actions tensor([15.5097, 14.5663], grad_fn=<ViewBackward0>)
# std_actions tensor([0.0071, 0.8186], grad_fn=<SoftplusBackward0>)
# states tensor([-19.2199])
# mean_actions tensor([15.5743, 14.6552], grad_fn=<ViewBackward0>)
# std_actions tensor([0.0066, 0.8332], grad_fn=<SoftplusBackward0>)
# states tensor([-19.1129])
# mean_actions tensor([15.4678, 14.5810], grad_fn=<ViewBackward0>)
# std_actions tensor([0.0066, 0.8451], grad_fn=<SoftplusBackward0>)
# states tensor([-19.2129])
# mean_actions tensor([15.5314, 14.6639], grad_fn=<ViewBackward0>)
# std_actions tensor([0.0062, 0.8574], grad_fn=<SoftplusBackward0>)
# states tensor([-19.1889])
# mean_actions tensor([15.4962, 14.6517], grad_fn=<ViewBackward0>)
# std_actions tensor([0.0061, 0.8676], grad_fn=<SoftplusBackward0>)
# states tensor([-27.7981])
# mean_actions tensor([22.4494, 21.2340], grad_fn=<ViewBackward0>)
# std_actions tensor([5.7810e-04, 9.5390e-01], grad_fn=<SoftplusBackward0>)
# states tensor([-19.0849])
# mean_actions tensor([15.3849, 14.5824], grad_fn=<ViewBackward0>)
# std_actions tensor([0.0060, 0.8847], grad_fn=<SoftplusBackward0>)
# states tensor([-19.1519])
# mean_actions tensor([15.4276, 14.6380], grad_fn=<ViewBackward0>)
# std_actions tensor([0.0057, 0.8931], grad_fn=<SoftplusBackward0>)
# states tensor([-19.1416])
# mean_actions tensor([15.4089, 14.6341], grad_fn=<ViewBackward0>)
# std_actions tensor([0.0056, 0.9001], grad_fn=<SoftplusBackward0>)
# states tensor([-19.0904])
# mean_actions tensor([15.3582, 14.5985], grad_fn=<ViewBackward0>)
# std_actions tensor([0.0056, 0.9059], grad_fn=<SoftplusBackward0>)
# states tensor([-27.7981])
# mean_actions tensor([22.3751, 21.2623], grad_fn=<ViewBackward0>)
# std_actions tensor([5.0542e-04, 1.0072e+00], grad_fn=<SoftplusBackward0>)
# states tensor([-21.7770])
# mean_actions tensor([17.5092, 16.6605], grad_fn=<ViewBackward0>)
# std_actions tensor([0.0026, 0.9471], grad_fn=<SoftplusBackward0>)
# states tensor([-20.0591])
# mean_actions tensor([16.1167, 15.3483], grad_fn=<ViewBackward0>)
# std_actions tensor([0.0041, 0.9332], grad_fn=<SoftplusBackward0>)
# states tensor([-19.2646])
# mean_actions tensor([15.4697, 14.7428], grad_fn=<ViewBackward0>)
# std_actions tensor([0.0051, 0.9279], grad_fn=<SoftplusBackward0>)
# states tensor([-19.1628])
# mean_actions tensor([15.3820, 14.6670], grad_fn=<ViewBackward0>)
# std_actions tensor([0.0052, 0.9305], grad_fn=<SoftplusBackward0>)
# states tensor([-19.3121])
# mean_actions tensor([15.4973, 14.7832], grad_fn=<ViewBackward0>)
# std_actions tensor([0.0049, 0.9359], grad_fn=<SoftplusBackward0>)
# states tensor([-19.3420])
# mean_actions tensor([15.5169, 14.8078], grad_fn=<ViewBackward0>)
# std_actions tensor([0.0049, 0.9395], grad_fn=<SoftplusBackward0>)
# states tensor([-19.2940])
# mean_actions tensor([15.4741, 14.7726], grad_fn=<ViewBackward0>)
# std_actions tensor([0.0049, 0.9417], grad_fn=<SoftplusBackward0>)
# states tensor([-19.1696])
# mean_actions tensor([15.3703, 14.6788], grad_fn=<ViewBackward0>)
# std_actions tensor([0.0050, 0.9426], grad_fn=<SoftplusBackward0>)
# states tensor([-19.2832])
# mean_actions tensor([15.4584, 14.7670], grad_fn=<ViewBackward0>)
# std_actions tensor([0.0048, 0.9465], grad_fn=<SoftplusBackward0>)
# states tensor([-23.2362])
# mean_actions tensor([18.6356, 17.7965], grad_fn=<ViewBackward0>)
# std_actions tensor([0.0016, 0.9995], grad_fn=<SoftplusBackward0>)
# states tensor([-19.1071])
# mean_actions tensor([15.3110, 14.6343], grad_fn=<ViewBackward0>)
# std_actions tensor([0.0050, 0.9481], grad_fn=<SoftplusBackward0>)
# states tensor([-19.4308])
# mean_actions tensor([15.5692, 14.8831], grad_fn=<ViewBackward0>)
# std_actions tensor([0.0046, 0.9542], grad_fn=<SoftplusBackward0>)
# states tensor([-19.3354])
# mean_actions tensor([15.4902, 14.8109], grad_fn=<ViewBackward0>)
# std_actions tensor([0.0047, 0.9544], grad_fn=<SoftplusBackward0>)
# states tensor([-19.1732])
# mean_actions tensor([15.3577, 14.6875], grad_fn=<ViewBackward0>)
# std_actions tensor([0.0049, 0.9536], grad_fn=<SoftplusBackward0>)
# states tensor([-23.2362])
# mean_actions tensor([18.6225, 17.8015], grad_fn=<ViewBackward0>)
# std_actions tensor([0.0016, 1.0090], grad_fn=<SoftplusBackward0>)
# states tensor([0.])
# mean_actions tensor([-0.0178,  0.3904], grad_fn=<ViewBackward0>)
# std_actions tensor([0.5541, 0.6759], grad_fn=<SoftplusBackward0>)
# states tensor([-19.1423])
# mean_actions tensor([15.3083, 14.6530], grad_fn=<ViewBackward0>)
# std_actions tensor([0.0048, 0.9619], grad_fn=<SoftplusBackward0>)
# states tensor([-19.0855])
# mean_actions tensor([15.2436, 14.5987], grad_fn=<ViewBackward0>)
# std_actions tensor([0.0048, 0.9668], grad_fn=<SoftplusBackward0>)
# states tensor([-20.5210])
# mean_actions tensor([16.3768, 15.6864], grad_fn=<ViewBackward0>)
# std_actions tensor([0.0032, 0.9931], grad_fn=<SoftplusBackward0>)
# states tensor([-19.1109])
# mean_actions tensor([15.2314, 14.5995], grad_fn=<ViewBackward0>)
# std_actions tensor([0.0046, 0.9771], grad_fn=<SoftplusBackward0>)
# states tensor([-27.7981])
# mean_actions tensor([22.1645, 21.2261], grad_fn=<ViewBackward0>)
# std_actions tensor([3.8690e-04, 1.1126e+00], grad_fn=<SoftplusBackward0>)
# states tensor([-19.6794])
# mean_actions tensor([15.6595, 15.0182], grad_fn=<ViewBackward0>)
# std_actions tensor([0.0039, 0.9943], grad_fn=<SoftplusBackward0>)
# states tensor([-19.1889])
# mean_actions tensor([15.2560, 14.6374], grad_fn=<ViewBackward0>)
# std_actions tensor([0.0044, 0.9899], grad_fn=<SoftplusBackward0>)
# states tensor([-19.1623])
# mean_actions tensor([15.2245, 14.6113], grad_fn=<ViewBackward0>)
# std_actions tensor([0.0044, 0.9927], grad_fn=<SoftplusBackward0>)
# states tensor([-19.1416])
# mean_actions tensor([15.1988, 14.5903], grad_fn=<ViewBackward0>)
# std_actions tensor([0.0044, 0.9951], grad_fn=<SoftplusBackward0>)
# states tensor([-27.7981])
# mean_actions tensor([22.0919, 21.1847], grad_fn=<ViewBackward0>)
# std_actions tensor([3.6291e-04, 1.1367e+00], grad_fn=<SoftplusBackward0>)
# states tensor([-23.2362])
# mean_actions tensor([18.4464, 17.7030], grad_fn=<ViewBackward0>)
# std_actions tensor([0.0013, 1.0656], grad_fn=<SoftplusBackward0>)
# states tensor([-19.1889])
# mean_actions tensor([15.2141, 14.6135], grad_fn=<ViewBackward0>)
# std_actions tensor([0.0042, 1.0029], grad_fn=<SoftplusBackward0>)
# states tensor([-19.8929])
# mean_actions tensor([15.7690, 15.1463], grad_fn=<ViewBackward0>)
# std_actions tensor([0.0034, 1.0166], grad_fn=<SoftplusBackward0>)
# states tensor([-19.6794])
# mean_actions tensor([15.5933, 14.9804], grad_fn=<ViewBackward0>)
# std_actions tensor([0.0036, 1.0148], grad_fn=<SoftplusBackward0>)
# states tensor([-19.0849])
# mean_actions tensor([15.1148, 14.5250], grad_fn=<ViewBackward0>)
# std_actions tensor([0.0043, 1.0062], grad_fn=<SoftplusBackward0>)
# states tensor([-19.3938])
# mean_actions tensor([15.3564, 14.7576], grad_fn=<ViewBackward0>)
# std_actions tensor([0.0039, 1.0129], grad_fn=<SoftplusBackward0>)
# states tensor([-23.2362])
# ...
# states tensor([-19.8929])
# mean_actions tensor([-7.9190, 15.3441], grad_fn=<ViewBackward0>)
# std_actions tensor([9.7537e-05, 4.7154e-01], grad_fn=<SoftplusBackward0>)
# states tensor([-19.7683])
# mean_actions tensor([-7.8684, 15.2196], grad_fn=<ViewBackward0>)
# std_actions tensor([1.0400e-04, 4.7174e-01], grad_fn=<SoftplusBackward0>)
# states tensor([-19.1889])
# mean_actions tensor([-7.6364, 14.7479], grad_fn=<ViewBackward0>)
# std_actions tensor([1.3693e-04, 4.7677e-01], grad_fn=<SoftplusBackward0>)
# states tensor([-19.4676])
# mean_actions tensor([-7.7469, 14.9407], grad_fn=<ViewBackward0>)
# std_actions tensor([1.2085e-04, 4.7313e-01], grad_fn=<SoftplusBackward0>)
# states tensor([-19.3180])
# mean_actions tensor([-7.6866, 14.8058], grad_fn=<ViewBackward0>)
# std_actions tensor([1.3011e-04, 4.7396e-01], grad_fn=<SoftplusBackward0>)
# states tensor([-19.0953])
# mean_actions tensor([-7.5972, 14.6183], grad_fn=<ViewBackward0>)
# std_actions tensor([1.4481e-04, 4.7629e-01], grad_fn=<SoftplusBackward0>)
# states tensor([-19.2015])
# mean_actions tensor([-7.6395, 14.7036], grad_fn=<ViewBackward0>)
# std_actions tensor([1.3758e-04, 4.8306e-01], grad_fn=<SoftplusBackward0>)
# states tensor([-19.2979])
# mean_actions tensor([-7.6779, 14.7811], grad_fn=<ViewBackward0>)
# std_actions tensor([1.3134e-04, 4.8928e-01], grad_fn=<SoftplusBackward0>)
# states tensor([-19.1078])
# mean_actions tensor([-7.6021, 14.6379], grad_fn=<ViewBackward0>)
# std_actions tensor([1.4327e-04, 4.9762e-01], grad_fn=<SoftplusBackward0>)
# states tensor([-20.5210])
# mean_actions tensor([-8.1671, 15.7762], grad_fn=<ViewBackward0>)
# std_actions tensor([7.3317e-05, 4.9732e-01], grad_fn=<SoftplusBackward0>)
# states tensor([-19.8929])
# mean_actions tensor([-7.9178, 15.3367], grad_fn=<ViewBackward0>)
# std_actions tensor([9.7151e-05, 5.1594e-01], grad_fn=<SoftplusBackward0>)
# states tensor([-20.2676])
# mean_actions tensor([-8.0684, 15.6676], grad_fn=<ViewBackward0>)
# std_actions tensor([8.0756e-05, 5.2487e-01], grad_fn=<SoftplusBackward0>)
# states tensor([-19.1654])
# mean_actions tensor([-7.6297, 14.8506], grad_fn=<ViewBackward0>)
# std_actions tensor([1.3385e-04, 5.4497e-01], grad_fn=<SoftplusBackward0>)
# states tensor([-19.4308])
# mean_actions tensor([-7.7366, 15.0915], grad_fn=<ViewBackward0>)
# std_actions tensor([1.1724e-04, 5.5334e-01], grad_fn=<SoftplusBackward0>)
# states tensor([-19.2578])
# mean_actions tensor([-7.6684, 14.9874], grad_fn=<ViewBackward0>)
# std_actions tensor([1.2617e-04, 5.6400e-01], grad_fn=<SoftplusBackward0>)
# states tensor([-21.7770])
# mean_actions tensor([-8.6747, 16.9860], grad_fn=<ViewBackward0>)
# std_actions tensor([3.8497e-05, 5.5650e-01], grad_fn=<SoftplusBackward0>)
# states tensor([-19.0953])
# mean_actions tensor([-7.6048, 14.9059], grad_fn=<ViewBackward0>)
# std_actions tensor([1.3458e-04, 5.8319e-01], grad_fn=<SoftplusBackward0>)
# states tensor([-19.4103])
# mean_actions tensor([-7.7333, 15.2507], grad_fn=<ViewBackward0>)
# std_actions tensor([1.1328e-04, 6.1451e-01], grad_fn=<SoftplusBackward0>)
# states tensor([-19.1170])
# mean_actions tensor([-7.6185, 15.1009], grad_fn=<ViewBackward0>)
# std_actions tensor([1.2735e-04, 6.4869e-01], grad_fn=<SoftplusBackward0>)
# states tensor([-19.4103])
# mean_actions tensor([-7.7376, 15.4002], grad_fn=<ViewBackward0>)
# std_actions tensor([1.0908e-04, 6.7151e-01], grad_fn=<SoftplusBackward0>)
# states tensor([-19.6282])
# mean_actions tensor([-7.8263, 15.6311], grad_fn=<ViewBackward0>)
# std_actions tensor([9.7007e-05, 6.9371e-01], grad_fn=<SoftplusBackward0>)
# states tensor([0.])
# mean_actions tensor([-0.3579,  0.2007], grad_fn=<ViewBackward0>)
# std_actions tensor([0.4001, 0.5051], grad_fn=<SoftplusBackward0>)
# states tensor([-19.2006])
# mean_actions tensor([-7.6581, 15.3846], grad_fn=<ViewBackward0>)
# std_actions tensor([1.1234e-04, 7.3275e-01], grad_fn=<SoftplusBackward0>)
# best_50_MVO [-19.06584191437274]
# episode 39 score 150.37664478515322 avg score 123.35506447753505 time_steps 2500 learning_steps 4
# best_50_MVO [-19.06584191437274]
# episode 40 score 141.50330654786697 avg score 119.0097125190041 time_steps 2550 learning_steps 4
# best_50_MVO [-19.06584191437274]
# episode 41 score 141.45347929164933 avg score 114.63891090888472 time_steps 2600 learning_steps 4
# best_50_MVO [-19.06584191437274]
# episode 42 score 141.50309549413313 avg score 114.638493376486 time_steps 2650 learning_steps 4
# best_50_MVO [-19.06584191437274]
# episode 43 score 141.50304463589958 avg score 114.66340370526763 time_steps 2700 learning_steps 4
# best_50_MVO [-19.06584191437274]
# episode 44 score 141.50304358093328 avg score 114.66323995687848 time_steps 2750 learning_steps 4
# best_50_MVO [-19.06584191437274]
# episode 45 score 141.453522143036 avg score 114.6386287900586 time_steps 2800 learning_steps 4
# best_50_MVO [-19.06584191437274]
# episode 46 score 141.50310381049607 avg score 114.63877425991146 time_steps 2850 learning_steps 4
# best_50_MVO [-19.06584191437274]
# episode 47 score 141.45349160176283 avg score 114.63863960353716 time_steps 2900 learning_steps 4
# best_50_MVO [-19.06584191437274]
# episode 48 score 141.50310682951866 avg score 114.63870647864827 time_steps 2950 learning_steps 4
# states tensor([-19.1722])
# mean_actions tensor([-7.6478, 15.3985], grad_fn=<ViewBackward0>)
# std_actions tensor([1.0970e-04, 7.4721e-01], grad_fn=<SoftplusBackward0>)
# states tensor([-19.1119])
# mean_actions tensor([-9.2353, 15.5546], grad_fn=<ViewBackward0>)
# std_actions tensor([7.2576e-05, 7.4102e-01], grad_fn=<SoftplusBackward0>)
# states tensor([0.])
# mean_actions tensor([-0.3973,  0.2252], grad_fn=<ViewBackward0>)
# std_actions tensor([0.3827, 0.5011], grad_fn=<SoftplusBackward0>)
# states tensor([-19.1194])
# mean_actions tensor([-11.8360,  16.1340], grad_fn=<ViewBackward0>)
# std_actions tensor([2.6936e-05, 7.3499e-01], grad_fn=<SoftplusBackward0>)
# states tensor([-21.7770])
# mean_actions tensor([-14.6323,  18.9284], grad_fn=<ViewBackward0>)
# std_actions tensor([3.3537e-06, 7.3356e-01], grad_fn=<SoftplusBackward0>)
# states tensor([-19.1930])
# mean_actions tensor([-13.7964,  17.1595], grad_fn=<ViewBackward0>)
# std_actions tensor([9.0010e-06, 7.2096e-01], grad_fn=<SoftplusBackward0>)
# states tensor([-23.3393])
# mean_actions tensor([-17.7841,  21.4069], grad_fn=<ViewBackward0>)
# std_actions tensor([4.0581e-07, 7.2366e-01], grad_fn=<SoftplusBackward0>)
# states tensor([-20.2676])
# mean_actions tensor([-16.2377,  18.9992], grad_fn=<ViewBackward0>)
# std_actions tensor([1.7876e-06, 7.1435e-01], grad_fn=<SoftplusBackward0>)
# states tensor([-19.7767])
# mean_actions tensor([-16.5534,  18.9042], grad_fn=<ViewBackward0>)
# std_actions tensor([1.6321e-06, 7.1056e-01], grad_fn=<SoftplusBackward0>)
# states tensor([-19.2940])
# mean_actions tensor([-16.7794,  18.7640], grad_fn=<ViewBackward0>)
# std_actions tensor([1.5649e-06, 7.0763e-01], grad_fn=<SoftplusBackward0>)
# states tensor([-21.0473])
# mean_actions tensor([-18.9164,  20.8295], grad_fn=<ViewBackward0>)
# std_actions tensor([3.1536e-07, 7.1493e-01], grad_fn=<SoftplusBackward0>)
# states tensor([-21.7770])
# mean_actions tensor([-20.1405,  21.9124], grad_fn=<ViewBackward0>)
# std_actions tensor([1.2903e-07, 7.2248e-01], grad_fn=<SoftplusBackward0>)
# states tensor([-19.2665])
# mean_actions tensor([-18.2722,  19.6687], grad_fn=<ViewBackward0>)
# std_actions tensor([5.9846e-07, 7.2288e-01], grad_fn=<SoftplusBackward0>)
# states tensor([-19.8929])
# mean_actions tensor([-19.2948,  20.5823], grad_fn=<ViewBackward0>)
# std_actions tensor([2.8085e-07, 7.3023e-01], grad_fn=<SoftplusBackward0>)
# states tensor([-19.1098])
# mean_actions tensor([-18.9069,  20.0188], grad_fn=<ViewBackward0>)
# std_actions tensor([3.9072e-07, 7.3501e-01], grad_fn=<SoftplusBackward0>)
# states tensor([-19.8929])
# mean_actions tensor([-20.0344,  21.0741], grad_fn=<ViewBackward0>)
# std_actions tensor([1.6562e-07, 7.4379e-01], grad_fn=<SoftplusBackward0>)
# states tensor([-19.5177])
# mean_actions tensor([-19.9612,  20.9001], grad_fn=<ViewBackward0>)
# std_actions tensor([1.7598e-07, 7.4473e-01], grad_fn=<SoftplusBackward0>)
# states tensor([-19.1447])
# mean_actions tensor([-19.8503,  20.6980], grad_fn=<ViewBackward0>)
# std_actions tensor([1.9249e-07, 7.4545e-01], grad_fn=<SoftplusBackward0>)
# states tensor([-21.0473])
# mean_actions tensor([-22.0974,  22.9511], grad_fn=<ViewBackward0>)
# std_actions tensor([3.3542e-08, 7.5503e-01], grad_fn=<SoftplusBackward0>)
# states tensor([-20.0463])
# mean_actions tensor([-21.2773,  22.0273], grad_fn=<ViewBackward0>)
# std_actions tensor([6.3700e-08, 7.5298e-01], grad_fn=<SoftplusBackward0>)
# states tensor([-19.5177])
# mean_actions tensor([-20.9203,  21.5937], grad_fn=<ViewBackward0>)
# std_actions tensor([8.4326e-08, 7.5257e-01], grad_fn=<SoftplusBackward0>)
# states tensor([-19.0876])
# mean_actions tensor([-20.6396,  21.2475], grad_fn=<ViewBackward0>)
# std_actions tensor([1.0516e-07, 7.5234e-01], grad_fn=<SoftplusBackward0>)
# states tensor([0.])
# mean_actions tensor([-0.6290,  0.2088], grad_fn=<ViewBackward0>)
# std_actions tensor([0.3228, 0.5126], grad_fn=<SoftplusBackward0>)
# states tensor([-19.0876])
# mean_actions tensor([-20.9511,  21.4633], grad_fn=<ViewBackward0>)
# std_actions tensor([8.1061e-08, 7.5415e-01], grad_fn=<SoftplusBackward0>)
# states tensor([0.])
# mean_actions tensor([-0.6010,  0.1741], grad_fn=<ViewBackward0>)
# std_actions tensor([0.3282, 0.5092], grad_fn=<SoftplusBackward0>)
# states tensor([-19.4898])
# mean_actions tensor([-21.6524,  22.0940], grad_fn=<ViewBackward0>)
# std_actions tensor([4.5232e-08, 7.5558e-01], grad_fn=<SoftplusBackward0>)
# states tensor([-19.2427])
# mean_actions tensor([-21.4867,  21.8915], grad_fn=<ViewBackward0>)
# std_actions tensor([5.0644e-08, 7.5392e-01], grad_fn=<SoftplusBackward0>)
# states tensor([-19.1619])
# mean_actions tensor([-21.4945,  21.8692], grad_fn=<ViewBackward0>)
# std_actions tensor([4.9597e-08, 7.5303e-01], grad_fn=<SoftplusBackward0>)
# states tensor([-19.3672])
# mean_actions tensor([-21.8149,  22.1671], grad_fn=<ViewBackward0>)
# std_actions tensor([3.8082e-08, 7.5344e-01], grad_fn=<SoftplusBackward0>)
# states tensor([-20.0463])
# mean_actions tensor([-22.6651,  23.0037], grad_fn=<ViewBackward0>)
# std_actions tensor([1.9326e-08, 7.5589e-01], grad_fn=<SoftplusBackward0>)
# states tensor([-19.2064])
# mean_actions tensor([-21.7859,  22.0908], grad_fn=<ViewBackward0>)
# std_actions tensor([3.8072e-08, 7.5194e-01], grad_fn=<SoftplusBackward0>)
# states tensor([-19.2932])
# mean_actions tensor([-21.9501,  22.2369], grad_fn=<ViewBackward0>)
# std_actions tensor([3.3146e-08, 7.5196e-01], grad_fn=<SoftplusBackward0>)
# states tensor([-19.1199])
# mean_actions tensor([-21.8109,  22.0783], grad_fn=<ViewBackward0>)
# std_actions tensor([3.6647e-08, 7.5091e-01], grad_fn=<SoftplusBackward0>)
# states tensor([-19.1542])
# mean_actions tensor([-21.9031,  22.1552], grad_fn=<ViewBackward0>)
# std_actions tensor([3.3820e-08, 7.5078e-01], grad_fn=<SoftplusBackward0>)
# states tensor([-23.3393])
# mean_actions tensor([-26.7565,  27.0377], grad_fn=<ViewBackward0>)
# std_actions tensor([7.4174e-10, 7.6740e-01], grad_fn=<SoftplusBackward0>)
# states tensor([-19.3201])
# mean_actions tensor([-22.1845,  22.4114], grad_fn=<ViewBackward0>)
# std_actions tensor([2.6744e-08, 7.5100e-01], grad_fn=<SoftplusBackward0>)
# states tensor([-19.0876])
# mean_actions tensor([-21.9555,  22.1686], grad_fn=<ViewBackward0>)
# std_actions tensor([3.1834e-08, 7.4982e-01], grad_fn=<SoftplusBackward0>)
# states tensor([-19.3201])
# mean_actions tensor([-22.2586,  22.4635], grad_fn=<ViewBackward0>)
# std_actions tensor([2.4949e-08, 7.5061e-01], grad_fn=<SoftplusBackward0>)
# states tensor([-19.1542])
# mean_actions tensor([-22.0985,  22.2926], grad_fn=<ViewBackward0>)
# std_actions tensor([2.8165e-08, 7.4975e-01], grad_fn=<SoftplusBackward0>)
# states tensor([-19.0873])
# mean_actions tensor([-22.0494,  22.2344], grad_fn=<ViewBackward0>)
# std_actions tensor([2.9153e-08, 7.4932e-01], grad_fn=<SoftplusBackward0>)
# states tensor([-19.1059])
# mean_actions tensor([-22.0963,  22.2739], grad_fn=<ViewBackward0>)
# std_actions tensor([2.7988e-08, 7.4927e-01], grad_fn=<SoftplusBackward0>)
# states tensor([-19.1059])
# mean_actions tensor([-22.1192,  22.2899], grad_fn=<ViewBackward0>)
# std_actions tensor([2.7394e-08, 7.4915e-01], grad_fn=<SoftplusBackward0>)
# states tensor([-19.5471])
# mean_actions tensor([-22.6521,  22.8196], grad_fn=<ViewBackward0>)
# std_actions tensor([1.7950e-08, 7.5086e-01], grad_fn=<SoftplusBackward0>)
# states tensor([-27.7981])
# mean_actions tensor([-32.2601,  32.4729], grad_fn=<ViewBackward0>)
# std_actions tensor([9.2821e-12, 7.8257e-01], grad_fn=<SoftplusBackward0>)
# states tensor([-19.4324])
# mean_actions tensor([nan, nan], grad_fn=<ViewBackward0>)
# std_actions tensor([nan, nan], grad_fn=<SoftplusBackward0>)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\Users\stefa\source\MIE1666H\rl-ccmvo\RL Actor_Critic.ipynb Cell 15 line 3
#      <a href='vscode-notebook-cell:/c%3A/Users/stefa/source/MIE1666H/rl-ccmvo/RL%20Actor_Critic.ipynb#X22sZmlsZQ%3D%3D?line=28'>29</a> # if total training steps can be divided by learning interval
#      <a href='vscode-notebook-cell:/c%3A/Users/stefa/source/MIE1666H/rl-ccmvo/RL%20Actor_Critic.ipynb#X22sZmlsZQ%3D%3D?line=29'>30</a> # perform gradient ascent in Agent
#      <a href='vscode-notebook-cell:/c%3A/Users/stefa/source/MIE1666H/rl-ccmvo/RL%20Actor_Critic.ipynb#X22sZmlsZQ%3D%3D?line=30'>31</a> if n_steps % N == 0:
# ---> <a href='vscode-notebook-cell:/c%3A/Users/stefa/source/MIE1666H/rl-ccmvo/RL%20Actor_Critic.ipynb#X22sZmlsZQ%3D%3D?line=31'>32</a>     agent.learn()
#      <a href='vscode-notebook-cell:/c%3A/Users/stefa/source/MIE1666H/rl-ccmvo/RL%20Actor_Critic.ipynb#X22sZmlsZQ%3D%3D?line=32'>33</a>     learn_iters+=1
#      <a href='vscode-notebook-cell:/c%3A/Users/stefa/source/MIE1666H/rl-ccmvo/RL%20Actor_Critic.ipynb#X22sZmlsZQ%3D%3D?line=34'>35</a> # store new observation as current observation
#
# c:\Users\stefa\source\MIE1666H\rl-ccmvo\RL Actor_Critic.ipynb Cell 15 line 1
#     <a href='vscode-notebook-cell:/c%3A/Users/stefa/source/MIE1666H/rl-ccmvo/RL%20Actor_Critic.ipynb#X22sZmlsZQ%3D%3D?line=162'>163</a> print('mean_actions', mean_actions)
#     <a href='vscode-notebook-cell:/c%3A/Users/stefa/source/MIE1666H/rl-ccmvo/RL%20Actor_Critic.ipynb#X22sZmlsZQ%3D%3D?line=163'>164</a> print('std_actions',std_actions)
# --> <a href='vscode-notebook-cell:/c%3A/Users/stefa/source/MIE1666H/rl-ccmvo/RL%20Actor_Critic.ipynb#X22sZmlsZQ%3D%3D?line=164'>165</a> dist = Normal(mean_actions, std_actions)
#     <a href='vscode-notebook-cell:/c%3A/Users/stefa/source/MIE1666H/rl-ccmvo/RL%20Actor_Critic.ipynb#X22sZmlsZQ%3D%3D?line=165'>166</a> new_probs = dist.log_prob(actions)
#     <a href='vscode-notebook-cell:/c%3A/Users/stefa/source/MIE1666H/rl-ccmvo/RL%20Actor_Critic.ipynb#X22sZmlsZQ%3D%3D?line=166'>167</a> prob_ratio = new_probs.exp() / old_probs.exp()
#
# File c:\Users\stefa\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\distributions\normal.py:56, in Normal.__init__(self, loc, scale, validate_args)
#      54 else:
#      55     batch_shape = self.loc.size()
# ---> 56 super().__init__(batch_shape, validate_args=validate_args)
#
# File c:\Users\stefa\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\distributions\distribution.py:68, in Distribution.__init__(self, batch_shape, event_shape, validate_args)
#      66         valid = constraint.check(value)
#      67         if not valid.all():
# ---> 68             raise ValueError(
#      69                 f"Expected parameter {param} "
#      70                 f"({type(value).__name__} of shape {tuple(value.shape)}) "
#      71                 f"of distribution {repr(self)} "
#      72                 f"to satisfy the constraint {repr(constraint)}, "
#      73                 f"but found invalid values:\n{value}"
#      74             )
#      75 super().__init__()
#
# ValueError: Expected parameter loc (Tensor of shape (2,)) of distribution Normal(loc: torch.Size([2]), scale: torch.Size([2])) to satisfy the constraint Real(), but found invalid values:
# tensor([nan, nan], grad_fn=<ViewBackward0>)

# %% [markdown]
# ## Best Predicted Portfolio

# %%
best_portfolio_indices = best_50_index

best_portfolio_mu = df_mu[best_portfolio_indices]
best_portfolio_Q = df_Q[best_portfolio_indices].loc[best_portfolio_indices]

w, ret = MVO(best_portfolio_mu,best_portfolio_Q,gamma=1)

print('Best Predicted MVO Value',ret)
# Out:
# Best Predicted MVO Value [-19.034886185977346]

# %% [markdown]
# ## Random Search Portfolio

# %%
returns = []
for _ in range(2000):
    rand_portfolio_indices = list(np.random.choice(1000, 50, replace=False))

    rand_portfolio_mu = df_mu[rand_portfolio_indices]
    rand_portfolio_Q = df_Q[rand_portfolio_indices].loc[rand_portfolio_indices]

    w, ret = MVO(rand_portfolio_mu,rand_portfolio_Q,gamma=1)

    # print(ret)

    returns.append(ret)

returns = np.array(returns)
print('Best Random Portfolio MVO Vlaue', returns.max())
# Out:
# Best Random Portfolio MVO Vlaue -19.574344604269527

# %% [markdown]
# ## To-Do List

# %% [markdown]
# 0) exponential reward
# 1) add more to state space
# 1.1) sharpe ratio
# 2) add spatial pooling to state space
# 3) change neural networks
# 4) parameter tweeking
# 5) save actor model and call it
# 6) look at the minimum reward of the 50 portfolios at end of each game
