# %% [markdown]
# ## PPO

# %% [markdown]
# ### Imports

# %%
import os
import numpy as np
import pandas as pd
import torch as T
import torch.nn as nn
import torch.optim as optim
from torch.distributions import Normal 
import torch
from gym import Env
from gym.spaces import Discrete, Box

import cvxpy as cp

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ### PPO Memory Class

# %%
#Code inspired by https://www.youtube.com/watch?v=K2qjAixgLqk
class PPOMemory:
    def __init__(self, batch_size):
        self.states = []
        self.probs = []
        self.vals = []
        self.actions = []
        self.rewards =[]
        self.dones =[]

        self.batch_size = batch_size
    
    def generate_batches(self):
        n_states = len(self.states)
        batch_start = np.arange(0, n_states, self.batch_size)
        indices = np.arange(n_states, dtype= np.int64)
        np.random.shuffle(indices)
        batches = [indices[i:i + self.batch_size] for i in batch_start][0]

        return np.array(self.states),\
                np.array(self.actions),\
                np.array(self.probs),\
                np.array(self.vals),\
                np.array(self.rewards),\
                np.array(self.dones),\
                batches
    def store_memory(self, state, action, prob, val, reward, done):
        self.states.append(state)
        self.actions.append(action)
        self.probs.append(prob)
        self.vals.append(val)
        self.rewards.append(reward)
        self.dones.append(done)
    
    def clear_memory(self):
        self.states = []
        self.probs = []
        self.actions =[]
        self.rewards = []
        self.dones = []
        self.vals =[]

class ActorNetwork(nn.Module):
    def __init__(self, n_actions, input_dims, alpha, fc1_dims=256, fc2_dims=256, chkpt_dir='checkpoint_directory/'):
        super(ActorNetwork, self).__init__()

        self.checkpoint_file = os.path.join(chkpt_dir, 'actor_torch_ppo')
        self.input_layer = nn.Linear(input_dims, fc1_dims)
        self.hidden_1 = nn.Linear(fc1_dims,fc2_dims)
        self.mean = nn.Linear(fc2_dims,n_actions)
        self.std = nn.Linear(fc2_dims, n_actions)

        self.optimizer = optim.Adam(self.parameters(), lr=alpha)
        self.device = T.device('cuda:0' if T.cuda.is_available() else 'cpu')
        self.to(self.device)
    
    def forward(self, state):
        input = self.input_layer(state)
        output = nn.functional.relu(input)
        h1 = self.hidden_1(output)
        h1_output = nn.functional.relu(h1)
        mean = self.mean(h1_output)
        # std = nn.functional.softplus(T.exp(self.std(h1_output)))  #ensures that the std is positive
        std = nn.functional.softplus(self.std(h1_output))
        return mean.flatten(), std.flatten()

    def save_checkpoint(self):
        T.save(self.state_dict(), self.checkpoint_file)
    def load_checkpoint(self):
        self.load_state_dict(T.load(self.checkpoint_file))

class CriticNetwork(nn.Module):
    def __init__(self, input_dims, alpha, fc1_dims=256, fc2_dims=256, chkpt_dir = 'checkpoint_directory/'):
        super(CriticNetwork, self).__init__()
        self.checkpoint_file = os.path.join(chkpt_dir, 'critic_torch_ppo')
        
        self.critic = nn.Sequential(
                                    nn.Linear(input_dims, fc1_dims),
                                    nn.ReLU(),
                                    nn.Linear(fc1_dims, fc2_dims),
                                    nn.ReLU(),
                                    nn.Linear(fc2_dims, 1)
        )

        self.optimizer = optim.Adam(self.parameters(), lr = alpha)
        self.device = T.device('cuda:0' if T.cuda.is_available() else 'cpu')
        self.cpu().to(self.device)

    def forward(self, state):
        value = self.critic(state)

        return value
    def save_checkpoint(self):
        T.save(self.state_dict(), self.checkpoint_file)
        
    def load_checkpoint(self):
        self.load_state_dict(T.load(self.checkpoint_file))

class Agent:
    def __init__(self, n_actions, input_dims, gamma=0.99, alpha=0.0003, gae_lambda=0.95, 
                 policy_clip=0.1, batch_size=64, N=2048, n_epochs =10):
        
        self.gamma = gamma
        self.gae_lambda = gae_lambda
        self.policy_clip = policy_clip
        self.n_epochs = n_epochs

        self.actor = ActorNetwork(n_actions, input_dims, alpha)
        self.critic = CriticNetwork(input_dims, alpha)
        self.memory = PPOMemory(batch_size)
    
    def remember(self, state, action, probs, vals, reward, done):
        self.memory.store_memory(state, action, probs, vals, reward, done)
    
    def save_models(self):
        # print('.....saving models.....')
        self.actor.save_checkpoint()
        self.critic.save_checkpoint()

    def load_models(self):
        print('.....loading models.....')
        self.actor.load_checkpoint()
        self.critic.load_checkpoint()
    
    def choose_action(self, observation):
        state = T.tensor([observation], dtype=T.float).to(self.actor.device)
        mean_actions, std_actions = self.actor(state)
        value = self.critic(state)

        dist = Normal(mean_actions, std_actions)
        sampled_actions = dist.sample()
        probs = dist.log_prob(sampled_actions)
        probs = probs.cpu().detach().numpy()
    
        action = sampled_actions.cpu().numpy()

        value = T.squeeze(value).item()

        return action, probs, value, #mean_actions, std_actions
    
    def learn(self):
        for _ in range(self.n_epochs):
            state_arr, action_arr, old_probs_arr, vals_arr, reward_arr, done_arr, batches = self.memory.generate_batches()

            values = vals_arr

            advantage = np.zeros(len(reward_arr), dtype = np.float32)

            for t in range(len(reward_arr)-1):
                discount = 1
                a_t=0
                for k in range(t, len(reward_arr)-1):
                    a_t += discount*(reward_arr[k] + self.gamma*values[k+1]* (1-int(done_arr[k])) - values[k])
                    discount *= self.gamma * self.gae_lambda
                advantage[t] = a_t
            
            advantage = T.tensor(advantage).to(self.actor.device)
            values = T.tensor(values).to(self.actor.device)
            for batch in batches:
                states = T.tensor(state_arr[batch], dtype = T.float).to(self.actor.device)
                old_probs = T.tensor(old_probs_arr[batch]).to(self.actor.device)
                actions = T.tensor(action_arr[batch]).to(self.actor.device)  
                # print('states', states)
                mean_actions, std_actions = self.actor(states)
                # print('mean_actions', mean_actions)
                # print('std_actions',std_actions)
                dist = Normal(mean_actions, std_actions)
                new_probs = dist.log_prob(actions)
                prob_ratio = new_probs.exp() / old_probs.exp()

                critic_value = self.critic(states)
                critic_value = T.squeeze(critic_value)

                weighted_probs = advantage[batch] *prob_ratio
                weighted_clipped_probs = T.clamp(prob_ratio, 1-self.policy_clip, 1+self.policy_clip) * advantage[batch]
                actor_loss = -T.min(weighted_probs, weighted_clipped_probs).mean()

                returns = advantage[batch] + values[batch]
                critic_loss = (returns-critic_value)**2
                critic_loss = critic_loss.mean()

                total_loss = actor_loss + 0.5*critic_loss
                self.actor.optimizer.zero_grad()
                self.critic.optimizer.zero_grad()
                total_loss.backward()
                self.actor.optimizer.step()
                self.critic.optimizer.step()
        self.memory.clear_memory()

# %%
class Environment(Env):
    def __init__(self):
        self.observation_space = Box(low=-np.inf, high=np.inf)
        self.action_space = Box(np.array([-np.inf, -np.inf]), np.array([np.inf, np.inf]))
        self.asset_length = 0
        self.cur_mu =[]
        self.cur_var = []
        self.portfolio_index=[]
        self.portfolio_mu=[]
        self.portfolio_Q =[]
        
    def step(self, action, stock_vector, df_Q, old_observation, mvo_gamma, MVO, derivative, find_stock):
        self.cur_mu.append(action[0])
        self.cur_var.append(action[1])
        self.portfolio_index, self.portfolio_mu, self.portfolio_Q = find_stock(self.cur_mu[-1],self.cur_var[-1], stock_vector, df_Q, self.portfolio_index, self.portfolio_mu, self.portfolio_Q)

        w, self.state = MVO(np.array(self.portfolio_mu), self.portfolio_Q, mvo_gamma) 
        
        # self.transition = derivative(self.portfolio_mu,self.portfolio_Q, mvo_gamma, w)
        # reward = self.transition.item()

        self.transition = np.exp(self.state[0] - old_observation[0])
        reward = self.transition

        self.asset_length += 1
        self.done = (self.asset_length >= 50)

        return self.state, reward, self.done, self.portfolio_index 
    
    def reset(self):
        self.state = np.array([0])
        self.asset_length = 0
        self.cur_mu =[]
        self.cur_var = []
        self.portfolio_index=[]
        self.portfolio_mu=[]
        self.portfolio_Q =[]
        return self.state

# %%
def find_stock(mu,var, stock_vector, df_Q, portfolio_index, portfolio_mu, portfolio_Q):

    # combine predicted mu and var into 2-D array
    stock = np.hstack((mu,var))

    # initialize distance
    smallest_distance = np.inf

    # for all the 2-D stocks in the 1000 synthetic dataset,
    # calculate the euclidean distance from predicted stock
    for i,s in enumerate(stock_vector):
        distance = np.linalg.norm(stock - s)

        # choose stock that is closest distance to predicted stock
        # do not choose a stock that has already been chosen
        if (distance < smallest_distance) and (i not in portfolio_index):
            smallest_distance = distance
            stock_index = i
    
    # find chosen stock mu and append
    stock_mu = stock_vector[i][0]
    portfolio_mu.append(stock_mu)

    # append chosen stock index to portfolio index
    portfolio_index.append(stock_index)

    # apped chosen stock to current portfolio Q matrix
    portfolio_Q = df_Q[portfolio_index].loc[portfolio_index]
    portfolio_Q = np.array(portfolio_Q)

    return portfolio_index, portfolio_mu, portfolio_Q

# %%
def MVO(mu,Q,gamma=1):

    # number of stocks 
    n = len(mu)

    # if there is only one stock in the portfolio,
    # the matrix multiplication is different as Q is not a matrix but a 1-D vector
    if n == 1:

      # define weights
      w = cp.Variable(n)

      # define constraints
      constraints = [
          cp.sum(w) == 1, # Sum to 1
          w>=0 # Disallow Short Sales
      ]

      # objective function
      risk = w*Q
      targetRet=gamma*mu@w
      prob = cp.Problem(cp.Maximize(targetRet - risk), constraints=constraints)
      prob.solve()
      
      return w.value,targetRet.value-risk.value
    
    # if there are multiple stocks in the portfolio,
    # the matrix multiplication is quad_form as Q is a (n,n) matrix

    else:
      # define weights
      w = cp.Variable(n)

      # define constraints
      constraints = [
          cp.sum(w) == 1, # Sum to 1
          w>=0 # Disallow Short Sales
      ]

      # objective Function
      risk = cp.quad_form(w, Q)
      targetRet=gamma*mu.T@w
      prob = cp.Problem(cp.Maximize(targetRet - risk), constraints=constraints)
      prob.solve()

      return w.value,[targetRet.value-risk.value]

# %%
def derivative(mu,Q,gamma,w):

  # initialize risk
  risk=0

  # if portfolio has one stock,
  # derivative reduces to 1-D vector multiplication
  if len(mu)<=1:
     return (mu*gamma) - Q*w


  # if portfolio has more than one stock,
  # perform element-wise multiplication of Q-matrix with weights
  else:
    for i in range(len(mu)):
        risk+=Q[i][-1]*w[i]
    Ret=mu[-1]*gamma
        # Ret+=mu[-1]*gamma
    return Ret-risk

# %% [markdown]
# ## Load Data

# %%
path_to_data = 'Data\synthetic1000'
date = '2016-02-07'
df_mu = np.loadtxt('{}/{}/mu'.format(path_to_data, date))
df_Q = np.loadtxt('{}/{}/Q'.format(path_to_data, date))
df_Q = pd.DataFrame(df_Q)


# get the variance for each stock from the Q-matrix
# variance is the diagonal of the Q-matrix
df_var = []
for i in range(df_Q.shape[0]):
    for j in range(df_Q.shape[1]):
        if i==j:
            df_var.append(df_Q[i][j])
df_var = np.array(df_var)

# combine the mu and variance of each stock
# used to calculate the euclidean distance of predicted stock
stock_vector = []
for i in range(len(df_mu)):
    temp = np.hstack((df_mu[i],df_var[i]))
    stock_vector.append(temp)
stock_vector = np.array(stock_vector)

# %% [markdown]
# ## Constants

# %%
# define Environment object
env = Environment()

# learning interval
N = 500

# learning parameters
batch_size = 64
n_epochs = 10
alpha = 0.0003
gamma = 0.99
gae_lambda = 0.95
mvo_gamma =1 

# define number of actions for Actor
n_actions = env.action_space.shape[0]
# define input dimensions for Actor and Critic
input_dims = env.observation_space.shape[0]

# define Agent object
agent = Agent(n_actions, input_dims, gamma=gamma, alpha=alpha, gae_lambda=gae_lambda, 
                 policy_clip=0.1, batch_size=batch_size, N=N, n_epochs = n_epochs)

# training loop parameters
n_games = 800
best_score = -np.inf
score_history = []
learn_iters = 0
avg_score = 0
n_steps = 0
best_50_MVO = -np.inf
best_50_index = []

# %%
path_to_data = 'Data/real/asset_'+'weekly'+'.pkl'
path_to_pxs = 'Data/real/prices_'+'weekly'+'.pkl'
returns = pd.read_pickle(path_to_data).reset_index()
prices = pd.read_pickle(path_to_pxs).reset_index()
returns.head()
# Out:
#         date      AMZN      TSLA        HD  BABA        TM       MCD  \
# 0 2014-01-03 -0.005893 -0.005777 -0.005465   0.0 -0.011565 -0.005050
# 1 2014-01-10  0.003077 -0.025676  0.001465   0.0  0.002489 -0.007665
# 2 2014-01-17  0.004904  0.166690 -0.012316   0.0 -0.013409 -0.009081
# 3 2014-01-24 -0.030054  0.026998 -0.022716   0.0 -0.010991 -0.005267
# 4 2014-01-31 -0.074587  0.039003 -0.029181   0.0 -0.026468 -0.002753
#
#         NKE       LOW      SBUX  ...       CMS       AES       EBR       ATO  \
# 0 -0.007757 -0.012109 -0.018370  ... -0.017931 -0.021365 -0.027027 -0.014971
# 1 -0.014225  0.014913  0.009357  ...  0.031191  0.023239 -0.003968  0.023916
# 2 -0.045892 -0.038043 -0.035664  ... -0.025083 -0.015829 -0.059761  0.009168
# 3 -0.023709  0.004621  0.001068  ...  0.004162 -0.040559 -0.076271  0.014276
# 4  0.016748 -0.032197 -0.051480  ...  0.047099  0.028454 -0.027523  0.023886
#
#    AGR       BIP  EVRG       LNT      WTRG        NI
# 0  0.0 -0.007904   0.0 -0.017636 -0.017380 -0.012774
# 1  0.0  0.000257   0.0  0.023279 -0.006040  0.037277
# 2  0.0 -0.029034   0.0 -0.011182  0.021267  0.006534
# 3  0.0 -0.019582   0.0 -0.010528 -0.002975 -0.008852
# 4  0.0 -0.007018   0.0  0.034127  0.020887  0.023221
#
# [5 rows x 289 columns]

# %%
from scipy.stats import gmean
lookback = 30

# %% [markdown]
# ## Main

# %%
def train_for_date(date, env, agent):
    # training loop parameters
    n_games = 50
    best_score = -np.inf
    score_history = []
    learn_iters = 0
    avg_score = 0
    n_steps = 0
    best_50_MVO = -np.inf
    best_50_index = []

    ret_today = returns[(returns['date'] < date)].tail(lookback)
    ret_today = ret_today.reset_index().drop('date', axis=1)
    AssetReturns_np = ret_today.to_numpy()
    df_Q = np.cov(AssetReturns_np, rowvar=False)
    df_mu = 1 - (gmean(1+AssetReturns_np))
    df_Q = pd.DataFrame(df_Q)

    # get the variance for each stock from the Q-matrix
    # variance is the diagonal of the Q-matrix
    df_var = []
    for i in range(df_Q.shape[0]):
        for j in range(df_Q.shape[1]):
            if i==j:
                df_var.append(df_Q[i][j])
    df_var = np.array(df_var)

    # combine the mu and variance of each stock
    # used to calculate the euclidean distance of predicted stock
    stock_vector = []
    for i in range(len(df_mu)):
        temp = np.hstack((df_mu[i],df_var[i]))
        stock_vector.append(temp)
    stock_vector = np.array(stock_vector)

    # Training Loop for RL
    for i in range(n_games):
        try:
            # reset the environment
            observation = env.reset()
            done = False

            # score tracks the total accumulated reward
            score = 0
            # stock counter to indicate when 50 stocks are reached
            stock_counter=0

            # start Agent loop
            while not done:
                # observe the environment and let Agent choose an action
                action, probs, value = agent.choose_action(observation)
                
                # step the environment by updating new state space, reward recieved, and updating done
                observation_, reward, done, portfolio_index = env.step(action, stock_vector, df_Q, observation, mvo_gamma, MVO, derivative, find_stock)

                # increment n_steps
                n_steps+=1
                #increment reward total
                score+= reward
                
                # store (S,A,R,S') sequence in memory
                agent.remember(observation, action, probs, value, reward, done)

                # if total training steps can be divided by learning interval
                # perform gradient ascent in Agent
                if n_steps % N == 0:
                    agent.learn()
                    learn_iters+=1
                
                # store new observation as current observation
                observation = observation_

                # accumulate total rewards
                score_history.append(score)
                
                # get the average of the last 100 rewards
                avg_score=np.mean(score_history[-100:])

                # update the stock counter
                stock_counter+=1

                # when the RL is predicting the 50th stock in the portfolio
                # and the predicted MVO value is the highest yet
                if (stock_counter==49) and (observation[0] > best_50_MVO):
                    best_50_index = portfolio_index
                    best_50_MVO = observation

                # if the average score is better than the best
                # average score, than save the agent models
                if avg_score > best_score:
                    best_score = avg_score
                    agent.save_models()
                
            # print('best_50_MVO', best_50_MVO)
            # print('episode', i, 'score%.1f' % score, 'avg score%.1f' % avg_score,
            #           'time_steps', n_steps, 'learning_steps', learn_iters)
            print('episode', i, 'score', score, 'avg score', avg_score,
                    'time_steps', n_steps, 'learning_steps', learn_iters)
        except Exception as e:
            print(e)
            best_portfolio_mu = df_mu[best_50_index]
            best_portfolio_Q = df_Q[best_50_index].loc[best_50_index]
            w, ret = MVO(best_portfolio_mu,best_portfolio_Q,gamma=1)

            return w, ret
        
    best_portfolio_mu = df_mu[best_50_index]
    best_portfolio_Q = df_Q[best_50_index].loc[best_50_index]
    w, ret = MVO(best_portfolio_mu,best_portfolio_Q,gamma=1)
    weights_full = np.zeros(288)
    weights_full[best_50_index] = w
    return weights_full, ret

# %%
from datetime import datetime

def generate_date_list(data, start, end):
    start = datetime.fromisoformat(start)
    end = datetime.fromisoformat(end)

    # Train model from start_date to date
    mask = (data['date'] >= start) & (data['date'] <= end)

    data = data.loc[mask]
    return data.date.apply(lambda x: x.date()).unique().tolist()

# %%
# define Environment object
env = Environment()

# learning interval
N = 35

# learning parameters
batch_size = 64
n_epochs = 10
alpha = 0.0003
gamma = 0.99
gae_lambda = 0.95
mvo_gamma =1 

# define number of actions for Actor
n_actions = env.action_space.shape[0]
# define input dimensions for Actor and Critic
input_dims = env.observation_space.shape[0]

# define Agent object
agent = Agent(n_actions, input_dims, gamma=gamma, alpha=alpha, gae_lambda=gae_lambda, 
                policy_clip=0.1, batch_size=batch_size, N=N, n_epochs = n_epochs)

assets = [x for x in list(prices.columns) if not x=='date']
holdings = pd.DataFrame(columns=['date']+assets)
portVal = pd.DataFrame(columns=['date', 'Wealth'])
first = True
InitialValue = 100000

TRAIN_DATE_START = '2015-01-01'
TRAIN_DATE_END = '2018-01-01'
dates = generate_date_list(returns, TRAIN_DATE_START, TRAIN_DATE_END)
noShares = None

for date in dates:
    currentPrices = (prices[prices['date']==str(date)]
    .drop('date',axis=1)
    .values
    .flatten())

    # Update Portfolio Value
    if first:
        portVal.loc[len(portVal)] = [date] + [InitialValue]
        CurrentPortfolioValue = InitialValue
        first = False
    else:     
        CurrentPortfolioValue = np.dot(currentPrices,noShares)
        portVal.loc[len(portVal)] = [date] + [CurrentPortfolioValue]
    date = str(date)
    x, mvo_val = train_for_date(date, env, agent)

    # Update shares held
    # 50% of 100k = 50k. If price is 100 we have 50,000/100=50 shares
    print("x: {}. CurrentPortfolioValue: {}. currentPrices: {}".format(x, CurrentPortfolioValue, currentPrices))
    noShares = np.divide(x*CurrentPortfolioValue, currentPrices)
    print('Done {}'.format(date))
# Out:
# episode 0 score 49.994011199712716 avg score 25.493738753083022 time_steps 50 learning_steps 1
# episode 1 score 49.99417752407752 avg score 25.4938036188208 time_steps 100 learning_steps 2
# episode 2 score 49.99409435120445 avg score 25.493837585647448 time_steps 150 learning_steps 4
# episode 3 score 49.99408430210361 avg score 25.493895142543547 time_steps 200 learning_steps 5
# episode 4 score 49.99415944238252 avg score 25.49388637637476 time_steps 250 learning_steps 7
# episode 5 score 49.99414841439601 avg score 25.493754193238377 time_steps 300 learning_steps 8
# episode 6 score 49.993947367774005 avg score 25.493691111699903 time_steps 350 learning_steps 10
# episode 7 score 49.99408416344497 avg score 25.49382970804179 time_steps 400 learning_steps 11
# episode 8 score 49.99409510424102 avg score 25.493915107534058 time_steps 450 learning_steps 12
# episode 9 score 49.993980492013186 avg score 25.493758018172898 time_steps 500 learning_steps 14
# episode 10 score 49.99409584621951 avg score 25.493797658892667 time_steps 550 learning_steps 15
# episode 11 score 49.99408392597237 avg score 25.493931386162515 time_steps 600 learning_steps 17
# episode 12 score 49.994005284578996 avg score 25.49387661400258 time_steps 650 learning_steps 18
# episode 13 score 49.99409429973315 avg score 25.493736965611202 time_steps 700 learning_steps 20
# episode 14 score 49.99409573046393 avg score 25.493794623246004 time_steps 750 learning_steps 21
# episode 15 score 49.99395697845683 avg score 25.493784480169083 time_steps 800 learning_steps 22
# episode 16 score 49.99417821002024 avg score 25.493773987567696 time_steps 850 learning_steps 24
# episode 17 score 49.99417475585666 avg score 25.493835647516665 time_steps 900 learning_steps 25
# episode 18 score 49.99407640840392 avg score 25.493839926545917 time_steps 950 learning_steps 27
# episode 19 score 49.99408372157761 avg score 25.493811914068125 time_steps 1000 learning_steps 28
# episode 20 score 49.99408384231167 avg score 25.49373705315395 time_steps 1050 learning_steps 30
# episode 21 score 49.99400947996638 avg score 25.493841530220607 time_steps 1100 learning_steps 31
# episode 22 score 49.99409399180595 avg score 25.493877768968886 time_steps 1150 learning_steps 32
# episode 23 score 49.994083870992235 avg score 25.493889144549993 time_steps 1200 learning_steps 34
# episode 24 score 49.99406551372483 avg score 25.49400731550781 time_steps 1250 learning_steps 35
# episode 25 score 49.994069745504454 avg score 25.4940025970062 time_steps 1300 learning_steps 37
# episode 26 score 49.994094277492906 avg score 25.49381849280252 time_steps 1350 learning_steps 38
# episode 27 score 49.994069718329605 avg score 25.493740004026595 time_steps 1400 learning_steps 40
# episode 28 score 49.994168452834366 avg score 25.49370968758008 time_steps 1450 learning_steps 41
# episode 29 score 49.99408462862582 avg score 25.493821761170267 time_steps 1500 learning_steps 42
# episode 30 score 49.99408441790571 avg score 25.493865208721605 time_steps 1550 learning_steps 44
# episode 31 score 49.994177485646375 avg score 25.493700032797946 time_steps 1600 learning_steps 45
# episode 32 score 49.99401137407452 avg score 25.493634368003057 time_steps 1650 learning_steps 47
# episode 33 score 49.99417080988807 avg score 25.493732991484297 time_steps 1700 learning_steps 48
# episode 34 score 49.99403745069105 avg score 25.4937684571608 time_steps 1750 learning_steps 50
# episode 35 score 49.99414622432237 avg score 25.49366455791637 time_steps 1800 learning_steps 51
# episode 36 score 49.994084051576586 avg score 25.49372113019896 time_steps 1850 learning_steps 52
# episode 37 score 49.99415003049667 avg score 25.493746066769695 time_steps 1900 learning_steps 54
# episode 38 score 49.99417742126863 avg score 25.493744987662097 time_steps 1950 learning_steps 55
# episode 39 score 49.99414858160318 avg score 25.493787155671818 time_steps 2000 learning_steps 57
# episode 40 score 49.994097358259864 avg score 25.49377402775565 time_steps 2050 learning_steps 58
# episode 41 score 49.99417082298073 avg score 25.49378241224719 time_steps 2100 learning_steps 60
# episode 42 score 49.99417740599735 avg score 25.493781874830383 time_steps 2150 learning_steps 61
# episode 43 score 49.99409409460294 avg score 25.493783855675492 time_steps 2200 learning_steps 62
# episode 44 score 49.994102322151605 avg score 25.493703381801307 time_steps 2250 learning_steps 64
# episode 45 score 49.99406551371779 avg score 25.493825694991155 time_steps 2300 learning_steps 65
# episode 46 score 49.99408379296606 avg score 25.49395503200675 time_steps 2350 learning_steps 67
# episode 47 score 49.9941689555795 avg score 25.493760472577623 time_steps 2400 learning_steps 68
# episode 48 score 49.99417472000873 avg score 25.493771627894276 time_steps 2450 learning_steps 70
# episode 49 score 49.99409407083267 avg score 25.493815248893384 time_steps 2500 learning_steps 71
# x: [0.00000000e+00 0.00000000e+00 0.00000000e+00 8.61389341e-11
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  7.31931405e-11 0.00000000e+00 1.62128287e-10 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 6.78441967e-11
#  0.00000000e+00 8.21074759e-11 0.00000000e+00 9.08594603e-11
#  8.17783065e-11 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  7.42862124e-10 0.00000000e+00 0.00000000e+00 1.26643302e-10
#  8.32075248e-11 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 6.31102805e-11
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 2.85128521e-10
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 1.44587395e-06 1.58593747e-10
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 1.62980419e-10
#  0.00000000e+00 4.38290102e-10 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 8.54923251e-11
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 1.41213914e-10
#  2.94323968e-09 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  1.19491938e-10 9.99998541e-01 1.12373223e-09 0.00000000e+00
#  0.00000000e+00 1.57268899e-10 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 8.63864709e-11
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  7.42894533e-11 0.00000000e+00 8.87741605e-11 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 6.88991250e-11
#  0.00000000e+00 7.05909465e-11 6.17588129e-11 7.06380621e-11
#  0.00000000e+00 7.74142324e-11 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  6.13508364e-11 0.00000000e+00 0.00000000e+00 5.63926669e-11
#  0.00000000e+00 0.00000000e+00 7.11723295e-11 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  7.26070873e-11 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 8.89754262e-11 0.00000000e+00 6.11396190e-11
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 8.97325094e-11 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 6.52520666e-11 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 2.87120873e-09
#  0.00000000e+00 0.00000000e+00 8.30496513e-11 8.34163122e-11
#  0.00000000e+00 6.54887898e-11 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 7.60137095e-11 0.00000000e+00
#  0.00000000e+00 7.22506351e-11 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 5.34278281e-11 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  6.57404528e-11 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 9.67353517e-11
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  2.28245466e-10 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 8.45570508e-10 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00]. CurrentPortfolioValue: 100000. currentPrices: [  15.426        14.62066667   83.88909875  103.6         107.44897531
#    74.50779255   43.24018954   57.70054061   34.39567686           nan
#    23.10622329 1142.06         29.96067066           nan  124.5920885
#    27.55596708   71.17143866   10.29860706    4.39039029  192.11
#            nan  678.4         616.79         42.67973434   22.73504982
#    52.01411779   55.34         41.23144175           nan   43.62757853
#            nan   22.56878623    4.5725       56.33596405   30.30707995
#            nan   40.66503745   22.22739588  126.84         62.02558135
#    76.64146565   43.92579938   30.21311756   51.37316319   22.33649687
#            nan   30.31722966   66.54753526   72.66648327    3.08318507
#    20.04106432   58.38164626   19.8984848    34.11719963  117.66728257
#    35.02989001   21.39191924   18.01820671   51.81148596   22.03439137
#    63.79076385   29.6638985    27.05894178   44.95736709           nan
#    26.32085033   17.23898675   33.76875102   35.67695496           nan
#    27.76390246   49.75789435    8.72214782   23.07176948   22.47039783
#    23.68913569   24.86567082   65.93505744   62.25407368   48.84065833
#    15.02511278   81.04999193   42.11931394   30.65003497   27.10734071
#    28.91068753   47.19295193  163.4221277    81.31955993   43.0506187
#    32.50254806   24.13591474   80.81031515   20.73399751  285.21247499
#            nan    4.69103886   93.55173757   88.2701086    81.8387271
#    58.29479001   18.122792     41.63052485   45.11636501   21.23381271
#   124.79083387   26.01323467   37.85781471   55.37044471   66.64630939
#    46.05985637  123.90451861   31.07037944   75.60954613   58.55570626
#   111.34328302   71.17069202   84.57890081   58.39660827   97.89705217
#   410.16        123.07         40.6870184    33.28723354   69.86191619
#   120.38063508   13.22                 nan  134.73473457   15.49026952
#   192.65116608   21.28666667   37.69022971   59.11         13.6275
#    73.665       342.01         26.11         83.39486153   45.94871352
#    79.80003342   71.52042654   97.63199006  113.60723577   75.11261327
#   152.73339531   68.83222907  130.29422986   57.89621514   34.77974143
#    77.20142002  126.61268686   10.37519356   52.66892851  121.03596224
#   113.55579776   43.12970498   90.04731831   31.86445051  154.08319847
#    47.63554203  148.48224736  109.92446846   71.26461931   35.21417969
#    35.15929318   53.94177987  139.98017391   50.28779474   59.87398751
#    34.19375556           nan  113.28830437           nan   27.17094788
#   217.21236509   49.56690673   33.82241135   82.5158765   182.65568583
#    57.0137936   133.95249393  120.68635369   31.83770487           nan
#    52.40656593   47.70101609  106.54195472   18.013        68.90328579
#    34.67         46.82581809  124.6423311    25.12449918   23.17981097
#            nan   43.43204305   42.49790293   55.84096053           nan
#    48.26596346   39.81734272   22.55703961  160.78349401   28.3526198
#    21.39030008   15.58458181   16.52177279   16.7546046            nan
#    17.46822011   53.51236639   24.46511839   40.45004011    4.83423558
#    17.51620888   98.68120252   78.73542679   38.44066024   20.98780429
#    76.52822201   72.34         59.24         42.0221564    56.72567046
#    61.48052975    2.69        104.17423016   84.46950665   28.28134196
#    20.23020964   22.1608897    67.38         46.0930693     6.35926901
#    35.31                 nan   69.62140252   34.2060593            nan
#    57.91339636   43.1                  nan   18.83         57.05702192
#    40.47333333           nan   71.08679528   80.41         24.48905903
#    59.53          6.158        21.27173051   57.55327654   33.15118014
#    54.15068504   42.63323055   44.53809696   45.03057519   19.57710371
#    27.62059174   48.77580166   47.56568317   30.67195524   39.77577796
#    45.49715018   40.89935281           nan   47.21612877   26.95286141
#    60.59906849   35.007401     55.49670967   22.22462549           nan
#     3.48479099   16.98592746   10.50086559   26.75057756   10.09354804
#     1.81377086   45.02860732           nan   11.27344726           nan
#    25.08433098   21.59453664   12.18454714]
# Done 2015-01-02
# episode 0 score 49.995657178037234 avg score 25.495285875250993 time_steps 50 learning_steps 1
# episode 1 score 49.9957594026789 avg score 25.495343602055613 time_steps 100 learning_steps 2
# episode 2 score 49.995681167112174 avg score 25.495369723798145 time_steps 150 learning_steps 4
# episode 3 score 49.995576055264 avg score 25.495368384306158 time_steps 200 learning_steps 5
# episode 4 score 49.995533166891256 avg score 25.495331318118215 time_steps 250 learning_steps 7
# episode 5 score 49.99575462581952 avg score 25.49533062390716 time_steps 300 learning_steps 8
# episode 6 score 49.9956618956422 avg score 25.495446534875697 time_steps 350 learning_steps 10
# episode 7 score 49.99559342887952 avg score 25.49540700195449 time_steps 400 learning_steps 11
# episode 8 score 49.995669242333946 avg score 25.49542667967957 time_steps 450 learning_steps 12
# episode 9 score 49.99567066599464 avg score 25.495583765174967 time_steps 500 learning_steps 14
# episode 10 score 49.99575690383894 avg score 25.495512085136173 time_steps 550 learning_steps 15
# episode 11 score 49.99566921783762 avg score 25.49537749631385 time_steps 600 learning_steps 17
# episode 12 score 49.995669218435104 avg score 25.49540105843314 time_steps 650 learning_steps 18
# episode 13 score 49.995731455547144 avg score 25.49538824656187 time_steps 700 learning_steps 20
# episode 14 score 49.995760917995966 avg score 25.49536620297853 time_steps 750 learning_steps 21
# episode 15 score 49.995683189886876 avg score 25.49539854214174 time_steps 800 learning_steps 22
# episode 16 score 49.99559004963927 avg score 25.495373449510872 time_steps 850 learning_steps 24
# episode 17 score 49.99574923653052 avg score 25.495351323443856 time_steps 900 learning_steps 25
# episode 18 score 49.99572996626826 avg score 25.495351217886377 time_steps 950 learning_steps 27
# episode 19 score 49.99574149809222 avg score 25.495355325605843 time_steps 1000 learning_steps 28
# episode 20 score 49.995661877685365 avg score 25.495426210633596 time_steps 1050 learning_steps 30
# episode 21 score 49.99575951704214 avg score 25.495474241172246 time_steps 1100 learning_steps 31
# episode 22 score 49.995676557629345 avg score 25.495446376591467 time_steps 1150 learning_steps 32
# episode 23 score 49.995669171307846 avg score 25.495411466394465 time_steps 1200 learning_steps 34
# episode 24 score 49.995681512057565 avg score 25.49538453407631 time_steps 1250 learning_steps 35
# episode 25 score 49.99567834736025 avg score 25.49534906651474 time_steps 1300 learning_steps 37
# episode 26 score 49.995750421555364 avg score 25.495387666238233 time_steps 1350 learning_steps 38
# episode 27 score 49.995669208362024 avg score 25.49546198803021 time_steps 1400 learning_steps 40
# episode 28 score 49.99576148960366 avg score 25.495491068183682 time_steps 1450 learning_steps 41
# episode 29 score 49.99566187850831 avg score 25.49547708353905 time_steps 1500 learning_steps 42
# episode 30 score 49.99566935780273 avg score 25.495433600431223 time_steps 1550 learning_steps 44
# episode 31 score 49.99566941455259 avg score 25.495410576557603 time_steps 1600 learning_steps 45
# episode 32 score 49.99577215447505 avg score 25.495496697160533 time_steps 1650 learning_steps 47
# episode 33 score 49.995533207233294 avg score 25.49548069977795 time_steps 1700 learning_steps 48
# episode 34 score 49.99572558555701 avg score 25.495177200518366 time_steps 1750 learning_steps 50
# episode 35 score 49.99574957261474 avg score 25.495075675178892 time_steps 1800 learning_steps 51
# episode 36 score 49.99573143010533 avg score 25.4952550914083 time_steps 1850 learning_steps 52
# episode 37 score 49.995514171874646 avg score 25.495330012940936 time_steps 1900 learning_steps 54
# episode 38 score 49.99559558206951 avg score 25.495261541929203 time_steps 1950 learning_steps 55
# episode 39 score 49.995730135761605 avg score 25.49530336291247 time_steps 2000 learning_steps 57
# episode 40 score 49.99568108001969 avg score 25.495343974180447 time_steps 2050 learning_steps 58
# episode 41 score 49.99576668454569 avg score 25.495393792378533 time_steps 2100 learning_steps 60
# episode 42 score 49.995683143810396 avg score 25.495398390955074 time_steps 2150 learning_steps 61
# episode 43 score 49.995653925519655 avg score 25.49525902826239 time_steps 2200 learning_steps 62
# episode 44 score 49.995748098531394 avg score 25.49526628068976 time_steps 2250 learning_steps 64
# episode 45 score 49.995681401783045 avg score 25.495349703568507 time_steps 2300 learning_steps 65
# episode 46 score 49.99574974747111 avg score 25.495293176646285 time_steps 2350 learning_steps 67
# episode 47 score 49.995726914234446 avg score 25.49524998437676 time_steps 2400 learning_steps 68
# episode 48 score 49.99558539413128 avg score 25.49522728352321 time_steps 2450 learning_steps 70
# episode 49 score 49.99575065003914 avg score 25.4952323847938 time_steps 2500 learning_steps 71
# x: [0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  1.49023520e-10 0.00000000e+00 2.46247383e-10 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 1.50363698e-10
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 1.95412554e-10
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  3.89974378e-10 3.01937225e-10 0.00000000e+00 1.93599236e-10
#  1.57642965e-10 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 1.41899521e-10
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 3.74245027e-10
#  0.00000000e+00 3.44005935e-10 0.00000000e+00 0.00000000e+00
#  2.88910037e-10 0.00000000e+00 1.59529096e-02 3.27947955e-10
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 3.91507792e-10
#  0.00000000e+00 4.38204975e-10 2.95592096e-10 0.00000000e+00
#  2.59472220e-10 2.81390468e-10 0.00000000e+00 0.00000000e+00
#  2.65680402e-10 0.00000000e+00 0.00000000e+00 3.25142013e-10
#  7.76668617e-10 0.00000000e+00 0.00000000e+00 3.13024024e-10
#  3.05729607e-10 9.84047078e-01 5.70348537e-10 0.00000000e+00
#  3.07721944e-10 2.92398426e-10 2.37835027e-10 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 1.67739563e-10
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 1.67659980e-10
#  1.56407236e-10 3.21231402e-10 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 1.48066103e-10
#  0.00000000e+00 0.00000000e+00 1.29930845e-10 1.54022076e-10
#  3.41637577e-10 1.58603821e-10 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  1.39014948e-10 0.00000000e+00 0.00000000e+00 1.42807099e-10
#  0.00000000e+00 0.00000000e+00 1.52712734e-10 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 1.46095202e-10
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 1.47842622e-10 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 6.14139191e-10
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 3.08425054e-10 1.38592646e-10 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  1.55558850e-10 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  2.76762225e-10 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 5.08598378e-10 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00]. CurrentPortfolioValue: nan. currentPrices: [  14.8465       13.77733333   85.07326276  103.02        107.79952898
#    74.46784628   43.67700509   58.23748803   33.69880964           nan
#    23.99122435 1051.96         29.8680906            nan  121.06767185
#    28.14916384   72.06851918   10.19803472    4.45048118  187.81
#            nan  714.27        606.02         41.77762272   22.59674942
#    51.55292862   58.63         41.87808871           nan   44.29691664
#            nan   23.56340421    4.515        54.45007904   31.60414704
#            nan   42.96042226   21.99804363  131.57         61.53782228
#    73.66648604   41.96210262   28.72490301   48.39155186   21.43413052
#            nan   27.59062656   63.09082308   68.90080905    3.22001281
#    18.15652844   56.13035153   18.54238388   32.94446743  111.88165396
#    33.85387662   19.73462647   17.60517352   48.24223433   20.81913184
#    61.19232702   28.05702877   26.42687119   44.5517478            nan
#    24.72600004   16.62419879   34.03383871   34.15868665           nan
#    24.31566137   51.3437041     8.61642481   21.52902328   20.4459278
#    23.64978496   24.03971322   57.16506662   61.19935784   46.37869524
#    14.25287235   80.02874874   40.56390234   29.20106664   25.51965067
#    27.99552024   44.94173453  157.48745242   79.27419686   40.28953958
#    30.69415645   24.4052266    79.29728647   20.78259756  279.21608118
#            nan    4.44414208   92.6770411    90.84516436   82.16758536
#    58.18662097   18.42988568   45.53952849   45.04104554   22.12843872
#   126.37847873   25.65850874   38.11076224   55.24771507   69.44220334
#    46.68678434  120.68078481   30.40829095   77.85159576   60.60857743
#   115.19494768   76.64478381   85.12782229   57.87438657  102.81903758
#   411.04        122.21         41.57008922   33.62505535   70.50415092
#   124.48628093   14.65                 nan  138.27765786   16.14974882
#   201.45621697   22.19333333   37.71810709   58.82         14.5475
#    74.995       342.34         26.4675       82.80555194   45.54131012
#    78.76501353   68.22774691   94.64401161  114.99727428   72.82539423
#   154.08445891   69.88177801  124.93896024   56.76715406   33.0058105
#    76.29633366  132.04166183    9.95555533   51.21904044  119.23584187
#   113.9822984    42.94635165   85.11389675   30.95540462  154.2708324
#    46.94941754  143.74232243  107.10741991   70.05643648   35.30300243
#    35.85882929   52.6542034   142.50724962   48.09488098   58.46951531
#    34.06733053           nan  111.10640969           nan   26.24834542
#   211.26332335   48.03148184   34.38313288   82.3006249   174.79016854
#    58.52679957  142.01554263  127.99890226   32.95745961           nan
#    54.13642529   48.97237279  106.42674309   17.72         71.64284176
#    34.65         49.1157607   130.25766318   25.40976766   23.84549831
#            nan   46.52696298   44.09208153   57.80621036           nan
#    51.45963069   40.11557889   22.85810893  168.63348918   29.43362269
#    22.36667168   15.65640016   17.35648681   17.46532624           nan
#    17.41686457   55.22618437   25.06483043   40.82201439    4.78860693
#    16.66712874   93.80227156   82.5152622    37.72912164   21.1246317
#    77.33795331   71.84         58.16         42.11644695   56.83258475
#    57.0827934     2.63        102.27793262   81.69864233   28.59246783
#    20.99769814   21.52163327   67.11         45.41254506    6.69019022
#    36.035                nan   69.8667643    33.00023419           nan
#    56.99060501   42.93                 nan   18.55         54.8531623
#    41.94                 nan   74.33526099   82.6          24.47079724
#    58.27          6.214        21.26176157   58.15585695   33.37276996
#    53.45886445   42.12356396   44.89498441   45.04989056   19.01433362
#    27.66647312   51.05273728   48.13211202   30.25469953   40.09733436
#    45.80080191   40.70147726           nan   48.56392546   26.79471962
#    60.6543407    34.25381702   55.36276749   21.60727478           nan
#     3.41327989   16.32460485   10.18905827   26.85715357    9.50414377
#     1.80529529   44.50501886           nan   11.45669057           nan
#    25.14091218   21.39339528   12.20176912]
# Done 2015-01-09
# episode 0 score 49.99513723903977 avg score 25.49469682674403 time_steps 50 learning_steps 1
# episode 1 score 49.99513720285095 avg score 25.494720251899736 time_steps 100 learning_steps 2
# episode 2 score 49.995023225131135 avg score 25.494643400711965 time_steps 150 learning_steps 4
# episode 3 score 49.995186534364066 avg score 25.49465206558806 time_steps 200 learning_steps 5
# episode 4 score 49.99513703038639 avg score 25.49471825508337 time_steps 250 learning_steps 7
# episode 5 score 49.9951248753519 avg score 25.494823440976816 time_steps 300 learning_steps 8
# episode 6 score 49.99496440908157 avg score 25.494865882513185 time_steps 350 learning_steps 10
# episode 7 score 49.995138467759574 avg score 25.494855846215454 time_steps 400 learning_steps 11
# episode 8 score 49.99523188142429 avg score 25.49500402615972 time_steps 450 learning_steps 12
# episode 9 score 49.995116316883426 avg score 25.495047053791847 time_steps 500 learning_steps 14
# episode 10 score 49.99511630589478 avg score 25.495041960341595 time_steps 550 learning_steps 15
# episode 11 score 49.99521654301121 avg score 25.494894207978515 time_steps 600 learning_steps 17
# episode 12 score 49.995017245105984 avg score 25.494811919444775 time_steps 650 learning_steps 18
# episode 13 score 49.995124887042124 avg score 25.494949792703686 time_steps 700 learning_steps 20
# episode 14 score 49.995208116095284 avg score 25.49482408561474 time_steps 750 learning_steps 21
# episode 15 score 49.99504719629052 avg score 25.49468010406671 time_steps 800 learning_steps 22
# episode 16 score 49.99504315655608 avg score 25.49471713771751 time_steps 850 learning_steps 24
# episode 17 score 49.995125282319286 avg score 25.494780419135108 time_steps 900 learning_steps 25
# episode 18 score 49.99511440274184 avg score 25.494959195922696 time_steps 950 learning_steps 27
# episode 19 score 49.99521020448721 avg score 25.49499905710978 time_steps 1000 learning_steps 28
# episode 20 score 49.99512465033149 avg score 25.49486337906868 time_steps 1050 learning_steps 30
# episode 21 score 49.9951370764386 avg score 25.49470626507252 time_steps 1100 learning_steps 31
# episode 22 score 49.99513647850801 avg score 25.494687676633344 time_steps 1150 learning_steps 32
# episode 23 score 49.9950952187324 avg score 25.4946898894524 time_steps 1200 learning_steps 34
# episode 24 score 49.995124837302846 avg score 25.494813605363216 time_steps 1250 learning_steps 35
# episode 25 score 49.995137313141484 avg score 25.4949373726996 time_steps 1300 learning_steps 37
# episode 26 score 49.994964806413414 avg score 25.494780509001565 time_steps 1350 learning_steps 38
# episode 27 score 49.99497353299882 avg score 25.494645527563026 time_steps 1400 learning_steps 40
# episode 28 score 49.9950455011401 avg score 25.494587001592034 time_steps 1450 learning_steps 41
# episode 29 score 49.99519681520741 avg score 25.49469121984849 time_steps 1500 learning_steps 42
# episode 30 score 49.99521441061199 avg score 25.494758258978706 time_steps 1550 learning_steps 44
# episode 31 score 49.99501992482075 avg score 25.494801537455892 time_steps 1600 learning_steps 45
# episode 32 score 49.99510441375751 avg score 25.494840307307623 time_steps 1650 learning_steps 47
# episode 33 score 49.99518668116542 avg score 25.494780711754025 time_steps 1700 learning_steps 48
# episode 34 score 49.995214463280774 avg score 25.494820411124362 time_steps 1750 learning_steps 50
# episode 35 score 49.995214937811426 avg score 25.494869233522408 time_steps 1800 learning_steps 51
# episode 36 score 49.9949948805314 avg score 25.494765837109234 time_steps 1850 learning_steps 52
# episode 37 score 49.995136951307856 avg score 25.494746775194425 time_steps 1900 learning_steps 54
# episode 38 score 49.99503511310959 avg score 25.494769978960996 time_steps 1950 learning_steps 55
# episode 39 score 49.9952166947572 avg score 25.494781606578613 time_steps 2000 learning_steps 57
# episode 40 score 49.99512536395975 avg score 25.494954484398693 time_steps 2050 learning_steps 58
# episode 41 score 49.99513712235062 avg score 25.494960439212957 time_steps 2100 learning_steps 60
# episode 42 score 49.99521938064858 avg score 25.49478770632983 time_steps 2150 learning_steps 61
# episode 43 score 49.99518800462939 avg score 25.4947968448338 time_steps 2200 learning_steps 62
# episode 44 score 49.99513815140831 avg score 25.494889337936314 time_steps 2250 learning_steps 64
# episode 45 score 49.99521670629241 avg score 25.494895048542844 time_steps 2300 learning_steps 65
# episode 46 score 49.99497929524977 avg score 25.494836675249097 time_steps 2350 learning_steps 67
# episode 47 score 49.99504209216225 avg score 25.4947600602642 time_steps 2400 learning_steps 68
# episode 48 score 49.99513710846598 avg score 25.494823221977427 time_steps 2450 learning_steps 70
# episode 49 score 49.99512481076797 avg score 25.49494448879196 time_steps 2500 learning_steps 71
# x: [0.00000000e+00 0.00000000e+00 0.00000000e+00 8.47020491e-12
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 9.00318386e-12
#  0.00000000e+00 0.00000000e+00 1.16076765e-11 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 8.27415478e-12
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 1.00244479e-11
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 7.80565612e-12
#  8.06530271e-12 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 8.23608792e-12
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 2.14957680e-11
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 3.93499985e-07 2.44730888e-11
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 2.44730070e-11
#  0.00000000e+00 2.93490103e-11 0.00000000e+00 0.00000000e+00
#  1.78873098e-11 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 2.12326664e-11
#  3.37713254e-11 9.03216163e-12 0.00000000e+00 2.06850242e-11
#  1.74687934e-11 9.99999606e-01 3.22970752e-11 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 1.55063405e-11 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 8.64850517e-12
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 8.79581587e-12
#  8.48676952e-12 0.00000000e+00 8.81601181e-12 0.00000000e+00
#  0.00000000e+00 9.19372139e-12 0.00000000e+00 8.70290039e-12
#  0.00000000e+00 8.45132421e-12 7.09097241e-12 8.21231572e-12
#  0.00000000e+00 8.33293987e-12 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  7.04105294e-12 0.00000000e+00 0.00000000e+00 7.09768838e-12
#  0.00000000e+00 0.00000000e+00 8.07833656e-12 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 9.75687734e-12 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 9.29701517e-12 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 8.55345574e-12 0.00000000e+00 7.60822650e-12
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 7.58010354e-12 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 3.86657695e-11
#  0.00000000e+00 0.00000000e+00 8.67901718e-12 8.79430340e-12
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 7.31646985e-12 0.00000000e+00
#  8.67795164e-12 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  8.51962385e-12 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  1.58371275e-11 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 2.71619467e-11 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00]. CurrentPortfolioValue: nan. currentPrices: [  14.537        12.87133333   84.4487379    96.89        110.19355405
#    73.09369441   42.31195649   58.14373531   34.04513153           nan
#    23.15432117 1008.22         29.42723317           nan  118.12735796
#    26.63848941   69.46881646   10.0706431     4.54437319  182.91
#            nan  711.11        580.85         41.61084579   23.6954693
#    51.85370416   63.           40.86632816           nan   43.9234624
#            nan   21.48374843    4.37625      51.67945786   30.80534353
#            nan   39.66424966   21.21903687  129.72         60.88302243
#    71.56289633   42.33069295   30.06547723   47.02001065   22.1841493
#            nan   27.89161521   63.1762699    71.28185451    3.22001281
#    19.27425317   56.5067738    18.57480063   28.87527284  117.73008451
#    31.59231241   20.49906041   16.25768936   43.59790691   20.8816309
#    60.24587652   26.64274268   26.24989143   44.76561979           nan
#    24.44661021   17.10605963   33.46090725   33.77794445           nan
#    23.854042     54.49041559    8.50012951   21.38246239   19.40930157
#    22.85490034   23.12681272   54.77549046   59.8885974    43.71352249
#    12.90984551   79.42218314   39.76309637   27.62541256   24.12930063
#    27.78669012   43.43403848  148.98052411   75.43410637   37.77441866
#    29.05205372   26.46685534   82.73350222   20.45454721  278.28863894
#            nan    4.46968313   91.35273061   92.64069643   81.46288909
#    58.8106731    18.89052619   45.88165731   44.53359045   22.23010077
#   122.03437071   26.62291985   37.71393343   53.31633815   72.93165239
#    48.22701479  122.77311203   31.64373443   78.50353927   59.2725819
#   120.70620057   75.51997043   83.19309905   58.95882993  102.71431449
#   408.69        122.86         41.54190611   34.33212428   65.96128466
#   120.82821073   14.46                 nan  141.28348906   16.72679321
#   198.95509903   21.52666667   35.54367076   59.58         14.7425
#    79.745       352.75         27.0725       83.33441952   46.39206429
#    78.19973343   65.81948354   92.10875717  114.33285335   74.22833527
#   153.83952926   69.89004217  122.65127224   56.58039207   32.95417842
#    76.06802359  132.55170884   10.08868194   50.07928886  119.51618849
#   114.57920583   43.53808287   85.45214137   31.79268373  157.93416156
#    46.52540802  138.40551955  102.1286483    71.70065523   34.31787748
#    35.96528043   52.54335245  144.40432606   46.96598454   56.54672598
#    33.85662215           nan  108.98641274           nan   26.48663348
#   205.35683556   45.74247417   34.38313288   80.65312219  177.48991064
#    59.25103465  144.6984559   130.75331726   34.56178658           nan
#    57.41907178   51.78803283  105.14501371   17.489        74.20589972
#    33.09         50.64026288  134.61762652   25.4863031    24.67238063
#            nan   49.15027606   45.21670207   60.29572672           nan
#    52.71512641   40.50384863   23.35024147  174.40442039   30.47669566
#    22.99988339   15.43196782   17.92409234   18.23527468           nan
#    17.40219155   56.39954523   23.71771607   40.00021075    4.79340995
#    17.76778818   94.67514998   81.66961744   37.83346584   21.04101495
#    76.57129282   71.73         56.64         41.86893425   54.44228658
#    58.90860011    2.39        101.01159155   80.25914141   28.35134528
#    20.3384452    20.83798403   63.96         44.5577402     6.89153385
#    36.52                 nan   67.98273641   28.53622041           nan
#    55.89067068   42.41                 nan   18.33         56.04199509
#    41.67                 nan   72.10483297   78.4          23.93207446
#    56.85          6.184        21.57678017   59.81295307   34.48071906
#    54.33936339   42.96033001   46.30068395   45.0756444    19.47809786
#    28.30881247   53.18336379   49.54459914   31.87980074   41.77241882
#    46.9901045    42.27687102           nan   49.01078853   28.13548696
#    61.262335     35.42605876   57.37827838   21.59505001           nan
#     3.57555508   16.53306524   10.87637547   27.89246335    9.85041878
#     1.83919755   47.09879552           nan   11.40357657           nan
#    26.25367574   21.8841802    12.63231849]
# Done 2015-01-16
# episode 0 score 49.9952179576918 avg score 25.494905633568592 time_steps 50 learning_steps 1
# episode 1 score 49.99514332439549 avg score 25.494815555722575 time_steps 100 learning_steps 2
# episode 2 score 49.99520187968632 avg score 25.494727409142996 time_steps 150 learning_steps 4
# episode 3 score 49.99521266696765 avg score 25.494763249542647 time_steps 200 learning_steps 5
# episode 4 score 49.99520185585771 avg score 25.494778537207097 time_steps 250 learning_steps 7
# episode 5 score 49.99521189248492 avg score 25.494723279708566 time_steps 300 learning_steps 8
# episode 6 score 49.99520291128975 avg score 25.49472586997326 time_steps 350 learning_steps 10
# episode 7 score 49.99520176817033 avg score 25.494744659128813 time_steps 400 learning_steps 11
# episode 8 score 49.99515194823438 avg score 25.494758105667184 time_steps 450 learning_steps 12
# episode 9 score 49.99513063251829 avg score 25.494825506124936 time_steps 500 learning_steps 14
# episode 10 score 49.99513564948323 avg score 25.494830489500874 time_steps 550 learning_steps 15
# episode 11 score 49.995151851918145 avg score 25.494789047788263 time_steps 600 learning_steps 17
# episode 12 score 49.99513279966565 avg score 25.49482822233892 time_steps 650 learning_steps 18
# episode 13 score 49.99523058893396 avg score 25.49494968808519 time_steps 700 learning_steps 20
# episode 14 score 49.99513583117289 avg score 25.494921661564504 time_steps 750 learning_steps 21
# episode 15 score 49.99504928333616 avg score 25.494835505699783 time_steps 800 learning_steps 22
# episode 16 score 49.995151968870154 avg score 25.49486297813183 time_steps 850 learning_steps 24
# episode 17 score 49.995228761735476 avg score 25.494936285349713 time_steps 900 learning_steps 25
# episode 18 score 49.99512059809793 avg score 25.494874847686305 time_steps 950 learning_steps 27
# episode 19 score 49.99520192497059 avg score 25.4948275587464 time_steps 1000 learning_steps 28
# episode 20 score 49.99513352540784 avg score 25.494738837775667 time_steps 1050 learning_steps 30
# episode 21 score 49.99513612878377 avg score 25.494669522185358 time_steps 1100 learning_steps 31
# episode 22 score 49.995218863075095 avg score 25.49483941430856 time_steps 1150 learning_steps 32
# episode 23 score 49.995202590342345 avg score 25.494852315787654 time_steps 1200 learning_steps 34
# episode 24 score 49.99515542978596 avg score 25.494801556763132 time_steps 1250 learning_steps 35
# episode 25 score 49.99510848672149 avg score 25.494755228219987 time_steps 1300 learning_steps 37
# episode 26 score 49.99521871884498 avg score 25.494759953904104 time_steps 1350 learning_steps 38
# episode 27 score 49.995214128111485 avg score 25.494878627260437 time_steps 1400 learning_steps 40
# episode 28 score 49.995063704426194 avg score 25.494892681829356 time_steps 1450 learning_steps 41
# episode 29 score 49.9951402733939 avg score 25.494862984749812 time_steps 1500 learning_steps 42
# episode 30 score 49.99515279061143 avg score 25.494919139858215 time_steps 1550 learning_steps 44
# episode 31 score 49.995218600466075 avg score 25.494938282584407 time_steps 1600 learning_steps 45
# episode 32 score 49.99516538213091 avg score 25.49492875830842 time_steps 1650 learning_steps 47
# episode 33 score 49.99508551552502 avg score 25.494874080363534 time_steps 1700 learning_steps 48
# episode 34 score 49.99513650976775 avg score 25.494792690762164 time_steps 1750 learning_steps 50
# episode 35 score 49.99521864585182 avg score 25.49481682270169 time_steps 1800 learning_steps 51
# episode 36 score 49.99513167175912 avg score 25.49495607040997 time_steps 1850 learning_steps 52
# episode 37 score 49.99506785948241 avg score 25.49499596853034 time_steps 1900 learning_steps 54
# episode 38 score 49.99515225009226 avg score 25.49487303225802 time_steps 1950 learning_steps 55
# episode 39 score 49.99505020126395 avg score 25.494886948512775 time_steps 2000 learning_steps 57
# episode 40 score 49.99510868838381 avg score 25.494820576554034 time_steps 2050 learning_steps 58
# episode 41 score 49.99520136242563 avg score 25.494739345379063 time_steps 2100 learning_steps 60
# episode 42 score 49.995151836965384 avg score 25.494849443534036 time_steps 2150 learning_steps 61
# episode 43 score 49.9951385874551 avg score 25.49494808126393 time_steps 2200 learning_steps 62
# episode 44 score 49.995219533578364 avg score 25.49503090345939 time_steps 2250 learning_steps 64
# episode 45 score 49.99521687593322 avg score 25.49502756650454 time_steps 2300 learning_steps 65
# episode 46 score 49.9952210721115 avg score 25.49493924807302 time_steps 2350 learning_steps 67
# episode 47 score 49.99513575232932 avg score 25.4948343173186 time_steps 2400 learning_steps 68
# episode 48 score 49.99511944415968 avg score 25.494750276421282 time_steps 2450 learning_steps 70
# episode 49 score 49.99520221102753 avg score 25.49480387695613 time_steps 2500 learning_steps 71
# x: [0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  1.17939422e-11 0.00000000e+00 2.71188594e-11 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 1.37248775e-11
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 1.50039517e-11
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  3.47135964e-11 0.00000000e+00 0.00000000e+00 1.19878966e-11
#  1.29485980e-11 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 1.29541591e-11
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 3.27112885e-11
#  0.00000000e+00 3.08096855e-11 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 2.28805196e-02 3.57944812e-11
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 3.69918988e-11
#  0.00000000e+00 4.56926624e-11 3.05450517e-11 3.13904546e-11
#  2.89972927e-11 2.88804424e-11 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 2.84551372e-11 3.28939403e-11
#  7.79574093e-11 1.47452446e-11 0.00000000e+00 3.73839412e-11
#  2.57770961e-11 9.77119479e-01 5.87454308e-11 0.00000000e+00
#  0.00000000e+00 3.25390282e-11 3.87361884e-11 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 1.33678301e-11
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 1.34898734e-11
#  0.00000000e+00 1.22972560e-11 9.84493238e-12 1.28593360e-11
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  1.20781183e-11 0.00000000e+00 0.00000000e+00 1.21733567e-11
#  0.00000000e+00 0.00000000e+00 1.25548271e-11 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 1.51910177e-11 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 1.34209978e-11 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 1.43118379e-11 0.00000000e+00
# ...
#    36.79         52.49413362  135.18141488   24.17547082   26.19205625
#            nan   51.37650401   43.19559362   58.92604236           nan
#    55.92448734   39.8511053    22.66885056  183.86721885   27.16446486
#    23.53913465   14.90316431   21.30407039   18.25501695           nan
#    15.93489041   57.32401136   28.28343908   37.35748113    5.65781342
#    19.47381032  101.21714404  105.15754035   38.61604729   21.61873068
#    78.80236098   77.36         67.69         46.87316511   53.79689336
#    63.86812314    2.8         105.43622346   93.27037228   24.52733049
#    27.46231279   21.50387615   79.38         51.02612659    7.19853304
#    40.145                nan   69.58332428   28.23107283           nan
#    52.76176257   47.13                 nan   18.66         57.57843982
#    48.02666667           nan   99.98055584   84.91         27.47489277
#    60.98          7.062        21.28895629   53.00974304   30.53713977
#    50.89624164   42.52292957   42.4018762    43.00246092   17.45650716
#    26.8481509    49.34274949   44.52208606   31.12903747   37.8387257
#    46.66336641   39.13431474           nan   46.25032794   25.2381338
#    55.1697516    32.79639708   52.48456799   21.24862963           nan
#     2.95945943   15.39157404   10.32237113   27.37489089    9.53735203
#     1.4662727    45.32025427           nan   12.04043838           nan
#    24.17349907   21.86822253   12.69664448]
# Done 2015-03-20
# episode 0 score 49.995392396701774 avg score 25.494984541897797 time_steps 50 learning_steps 1
# episode 1 score 49.995408278023504 avg score 25.494997344240552 time_steps 100 learning_steps 2
# episode 2 score 49.99538716795439 avg score 25.49485799250668 time_steps 150 learning_steps 4
# episode 3 score 49.995198537649934 avg score 25.494685732300788 time_steps 200 learning_steps 5
# episode 4 score 49.99529981037448 avg score 25.494876622587302 time_steps 250 learning_steps 7
# episode 5 score 49.99539232154451 avg score 25.495072092529593 time_steps 300 learning_steps 8
# episode 6 score 49.99521348677757 avg score 25.494810123666674 time_steps 350 learning_steps 10
# episode 7 score 49.99538750711728 avg score 25.494613149788716 time_steps 400 learning_steps 11
# episode 8 score 49.995299755385666 avg score 25.494841397662505 time_steps 450 learning_steps 12
# episode 9 score 49.99538665020102 avg score 25.494867335849353 time_steps 500 learning_steps 14
# episode 10 score 49.99529411797508 avg score 25.495004306420707 time_steps 550 learning_steps 15
# episode 11 score 49.99523395847435 avg score 25.494972795864047 time_steps 600 learning_steps 17
# episode 12 score 49.99538663573992 avg score 25.494684925280787 time_steps 650 learning_steps 18
# episode 13 score 49.99522723904401 avg score 25.494690858403498 time_steps 700 learning_steps 20
# episode 14 score 49.9953298115081 avg score 25.494789469697118 time_steps 750 learning_steps 21
# episode 15 score 49.995299829664106 avg score 25.495028972401673 time_steps 800 learning_steps 22
# episode 16 score 49.995392550489505 avg score 25.495090896071655 time_steps 850 learning_steps 24
# episode 17 score 49.99533010662675 avg score 25.49504130287823 time_steps 900 learning_steps 25
# episode 18 score 49.9953872125678 avg score 25.494961061766798 time_steps 950 learning_steps 27
# episode 19 score 49.99538851083902 avg score 25.494859158913208 time_steps 1000 learning_steps 28
# episode 20 score 49.99511572764931 avg score 25.49487265033157 time_steps 1050 learning_steps 30
# episode 21 score 49.995387128191645 avg score 25.494874239654123 time_steps 1100 learning_steps 31
# episode 22 score 49.99538769606026 avg score 25.494826984095486 time_steps 1150 learning_steps 32
# episode 23 score 49.995408258736774 avg score 25.494955442672445 time_steps 1200 learning_steps 34
# episode 24 score 49.99541635741124 avg score 25.495167909059706 time_steps 1250 learning_steps 35
# episode 25 score 49.99529976174851 avg score 25.49518049901737 time_steps 1300 learning_steps 37
# episode 26 score 49.995392280446666 avg score 25.49505768967789 time_steps 1350 learning_steps 38
# episode 27 score 49.99529411759881 avg score 25.495142434315863 time_steps 1400 learning_steps 40
# episode 28 score 49.995169599647994 avg score 25.49507246670716 time_steps 1450 learning_steps 41
# episode 29 score 49.99538754314241 avg score 25.494671615656785 time_steps 1500 learning_steps 42
# episode 30 score 49.99529985065251 avg score 25.494809251503572 time_steps 1550 learning_steps 44
# episode 31 score 49.99530018057153 avg score 25.495202595906516 time_steps 1600 learning_steps 45
# episode 32 score 49.9953954601552 avg score 25.49511441205212 time_steps 1650 learning_steps 47
# episode 33 score 49.995299760906455 avg score 25.49502081074948 time_steps 1700 learning_steps 48
# episode 34 score 49.995329881574435 avg score 25.49504630007006 time_steps 1750 learning_steps 50
# episode 35 score 49.99508164668656 avg score 25.49492085686524 time_steps 1800 learning_steps 51
# episode 36 score 49.995299833324495 avg score 25.494927667739347 time_steps 1850 learning_steps 52
# episode 37 score 49.995327120997594 avg score 25.495003374524572 time_steps 1900 learning_steps 54
# episode 38 score 49.995325784358535 avg score 25.494862936977235 time_steps 1950 learning_steps 55
# episode 39 score 49.99522254465423 avg score 25.494680550216835 time_steps 2000 learning_steps 57
# episode 40 score 49.99532637639715 avg score 25.49476869301933 time_steps 2050 learning_steps 58
# episode 41 score 49.995125572424335 avg score 25.494897735613254 time_steps 2100 learning_steps 60
# episode 42 score 49.99532724291516 avg score 25.494827716582403 time_steps 2150 learning_steps 61
# episode 43 score 49.99529983840241 avg score 25.494947724826698 time_steps 2200 learning_steps 62
# episode 44 score 49.99516825199743 avg score 25.494789160844594 time_steps 2250 learning_steps 64
# episode 45 score 49.99513975240869 avg score 25.494689817331246 time_steps 2300 learning_steps 65
# episode 46 score 49.99538617451948 avg score 25.49472002226505 time_steps 2350 learning_steps 67
# episode 47 score 49.9952016749811 avg score 25.494519954309304 time_steps 2400 learning_steps 68
# episode 48 score 49.99519789942744 avg score 25.494593492841517 time_steps 2450 learning_steps 70
# episode 49 score 49.99539224254999 avg score 25.494814742500626 time_steps 2500 learning_steps 71
# x: [0.00000000e+00 0.00000000e+00 2.53290859e-08 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  2.05928111e-09 0.00000000e+00 6.77810854e-09 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 1.90471429e-09
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 2.38673077e-09
#  1.76533770e-09 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 2.20271790e-09
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  1.54894838e-08 0.00000000e+00 9.99998243e-01 2.04831995e-08
#  2.14402236e-08 0.00000000e+00 0.00000000e+00 1.17107466e-08
#  0.00000000e+00 1.52798409e-08 2.31239977e-08 0.00000000e+00
#  2.27085279e-08 2.34158552e-08 0.00000000e+00 0.00000000e+00
#  1.21379802e-08 0.00000000e+00 0.00000000e+00 1.75018731e-07
#  5.03443502e-08 4.27318789e-09 0.00000000e+00 2.30491482e-08
#  7.86670946e-09 1.05204609e-06 3.16957287e-08 1.88691913e-08
#  0.00000000e+00 2.62978966e-08 3.06007553e-08 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 9.94837408e-09 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 1.93956583e-09
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  2.10207918e-09 2.34586820e-09 1.70284589e-09 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 2.47307644e-09
#  0.00000000e+00 1.75655283e-09 0.00000000e+00 0.00000000e+00
#  2.36038340e-09 0.00000000e+00 0.00000000e+00 3.33188347e-09
#  0.00000000e+00 2.62067386e-09 1.44704046e-09 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 1.39106319e-08 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 1.42750089e-09 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 4.82551212e-08
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 1.88038532e-09
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 1.88899695e-08
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 2.32951665e-09 0.00000000e+00
#  2.19642301e-09 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  5.38994150e-09 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 2.35900625e-09 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00]. CurrentPortfolioValue: nan. currentPrices: [  18.528        12.33333333   92.83263061   84.58        125.01846922
#    78.12550162   45.57821891   63.00116164   40.29742207           nan
#    28.93568678 1135.19         30.75788698           nan  121.72404495
#    29.74463527   74.16133508   10.82545029    6.16682708  215.42
#            nan  662.72        681.34         41.98492264   25.84538736
#    59.65381666   64.32         45.90892684           nan   47.48924948
#            nan   24.86198336    4.64875      60.32981548   30.74122617
#            nan   46.34371529   22.78891344  151.2          56.26619937
#    71.67623902   40.97225466   30.41940167   47.41147751   23.55468926
#            nan   28.88515538   65.09134777   71.47917999    2.59972705
#    20.12984026   53.14811675   17.69937318   37.27854834  128.46921604
#    43.3695011    21.28184076   16.62956934   55.99470782   20.40645573
#    58.17725259   26.19739302   26.37389743   43.80351715           nan
#    29.04381359   13.85351373   37.14744796   32.80682914           nan
#    26.54312048   62.41116166    8.1406713    21.81443133   19.61212354
#    22.57249966   22.67856588   59.01972488   61.69338027   46.54282611
#    12.89165339   82.69195082   41.94775207   28.45369993   27.23363737
#    27.08979623   41.57689283  158.57778169   68.35887115   40.47258785
#    29.26684353   26.76402704   94.92798255   23.58754599  290.83761111
#            nan    5.47652395   91.65826707  103.70520207   79.11433886
#    61.66129924   23.21766339   42.37495201   39.77938471   23.60692884
#   130.36798385   26.61177779   39.6551541    54.89619171   74.46667654
#    50.51027099  126.64925134   34.10779571   81.78289028   63.28713891
#   139.28368015   75.73743435   83.60254048   55.24994475  122.83358343
#   454.5         120.34         43.50351493   37.48339563   71.84528815
#   124.96725176   17.83                 nan  167.53504305   19.51856394
#   210.45326456   23.94666667   38.2942398    67.26         15.04
#    76.585       429.87         34.61         73.49999136   46.94339611
#    82.3802993    62.53086398   89.66173587  130.93089352   74.87453842
#   160.97149018   70.3428797   130.44303644   56.4144207    33.66153326
#    79.27659549  139.31671433    9.65193006   52.12540146  121.37451241
#   111.25890527   44.81924709   85.95938846   32.26655772  147.23042885
#    43.94329101  162.77248787  101.07953505   74.8301213    34.91046218
#    37.98478978   58.04060276  154.2224045    50.00232668   64.56366021
#    33.85662215           nan  106.95240438           nan   29.46256206
#   200.56152667   48.88851892   33.80062007   79.51063288  186.48678519
#    61.39114019  142.33663284  127.41506225   33.67739141           nan
#    53.53755356   47.83467018  115.92210158   19.206        75.3109307
#    35.93         50.38743157  131.82875342   23.18628295   25.26088246
#            nan   49.71393006   42.36952842   56.80858437           nan
#    52.5346489    38.50763575   21.48995303  178.71542066   26.97884529
#    22.66688101   14.66903605   20.90797877   17.45216473           nan
#    14.84908757   55.59597082   27.68811649   35.69347019    5.15398598
#    18.03509119   93.5909431   101.14973553   37.07697043   20.6229312
#    80.92144502   73.31         66.55         44.88058117   51.48110761
#    63.67500897    2.72        103.83085857   90.14061867   25.06785614
#    26.35043843   20.35379322   78.47         49.16288339    7.07692946
#    39.2                  nan   63.26874519   26.25745703           nan
#    48.991879     45.79                 nan   18.08         57.05006968
#    48.81333333           nan   92.47484162   85.06         26.37223679
#    58.72          6.916        20.7968538    51.85510275   29.88524619
#    49.6271845    41.5317133    41.07911403   42.37149204   17.05164239
#    26.54709343   47.97567368   43.31252231   30.55243692   37.28083255
#    45.88309929   38.45151647           nan   45.11695345   24.03103229
#    53.51570592   31.82003927   51.57733198   20.50035135           nan
#     2.81093638   14.99169848   10.90678451   26.30076401    9.26994963
#     1.44084601   44.31403913           nan   12.1855039            nan
#    23.43589938   21.28528583   12.679323  ]
# Done 2015-03-27
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\Users\Rafay\Documents\PhD\Courses\MIE1666\RL Actor_Critic.ipynb Cell 19 line 4
#      <a href='vscode-notebook-cell:/c%3A/Users/Rafay/Documents/PhD/Courses/MIE1666/RL%20Actor_Critic.ipynb#X43sZmlsZQ%3D%3D?line=44'>45</a>     first = False
#      <a href='vscode-notebook-cell:/c%3A/Users/Rafay/Documents/PhD/Courses/MIE1666/RL%20Actor_Critic.ipynb#X43sZmlsZQ%3D%3D?line=45'>46</a> else:
# ---> <a href='vscode-notebook-cell:/c%3A/Users/Rafay/Documents/PhD/Courses/MIE1666/RL%20Actor_Critic.ipynb#X43sZmlsZQ%3D%3D?line=46'>47</a>     CurrentPortfolioValue = np.dot(currentPrices,noShares)
#      <a href='vscode-notebook-cell:/c%3A/Users/Rafay/Documents/PhD/Courses/MIE1666/RL%20Actor_Critic.ipynb#X43sZmlsZQ%3D%3D?line=47'>48</a>     portVal.loc[len(portVal)] = [date] + [CurrentPortfolioValue]
#      <a href='vscode-notebook-cell:/c%3A/Users/Rafay/Documents/PhD/Courses/MIE1666/RL%20Actor_Critic.ipynb#X43sZmlsZQ%3D%3D?line=48'>49</a> date = str(date)
#
# ValueError: shapes (0,) and (288,) not aligned: 0 (dim 0) != 288 (dim 0)

# %%
def agent_inference(date):
    ret_today = returns[(returns['date'] < date)].tail(lookback)
    ret_today = ret_today.reset_index().drop('date', axis=1)
    AssetReturns_np = ret_today.to_numpy()
    df_Q = np.cov(AssetReturns_np, rowvar=False)
    df_mu = 1 - (gmean(1+AssetReturns_np))
    df_Q = pd.DataFrame(df_Q)

    # get the variance for each stock from the Q-matrix
    # variance is the diagonal of the Q-matrix
    df_var = []
    for i in range(df_Q.shape[0]):
        for j in range(df_Q.shape[1]):
            if i==j:
                df_var.append(df_Q[i][j])
    df_var = np.array(df_var)

    # combine the mu and variance of each stock
    # used to calculate the euclidean distance of predicted stock
    stock_vector = []
    for i in range(len(df_mu)):
        temp = np.hstack((df_mu[i],df_var[i]))
        stock_vector.append(temp)
    stock_vector = np.array(stock_vector)

    observation = env.reset()

    done = False
    while not done:
        # observe the environment and let Agent choose an action
        action, probs, value = agent.choose_action(observation)
        
        # step the environment by updating new state space, reward recieved, and updating done
        observation_, reward, done, portfolio_index = env.step(action, stock_vector, df_Q, observation, mvo_gamma, MVO, derivative, find_stock)
        
        # store (S,A,R,S') sequence in memory
        agent.remember(observation, action, probs, value, reward, done)
        
        # store new observation as current observation
        observation = observation_
    
    best_50_index = portfolio_index
    best_portfolio_mu = df_mu[best_50_index]
    best_portfolio_Q = df_Q[best_50_index].loc[best_50_index]
    w, ret = MVO(best_portfolio_mu,best_portfolio_Q,gamma=1)
    weights_full = np.zeros(288)
    weights_full[best_50_index] = w

    return weights_full

# %%
w = agent_inference('2019-01-01')

# %%
first = True
InitialValue = 100000

TRAIN_DATE_START = '2019-01-01'
TRAIN_DATE_END = '2022-12-31'
dates = generate_date_list(returns, TRAIN_DATE_START, TRAIN_DATE_END)
noShares = None

for date in dates:
    currentPrices = (prices[prices['date']==str(date)]
    .drop('date',axis=1)
    .values
    .flatten())

    # Update Portfolio Value
    if first:
        portVal.loc[len(portVal)] = [date] + [InitialValue]
        CurrentPortfolioValue = InitialValue
        first = False
    else:     
        CurrentPortfolioValue = np.dot(currentPrices,noShares)
        portVal.loc[len(portVal)] = [date] + [CurrentPortfolioValue]
    date = str(date)

    # Update shares held
    # 50% of 100k = 50k. If price is 100 we have 50,000/100=50 shares
    print("x: {}. CurrentPortfolioValue: {}. currentPrices: {}".format(x, CurrentPortfolioValue, currentPrices))
    noShares = np.divide(x*CurrentPortfolioValue, currentPrices)
    print('Done {}'.format(date))

# %%
noShares
# Out:
# array([0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        9.91702296e-08,            nan, 5.76703897e-07, 0.00000000e+00,
#        0.00000000e+00,            nan, 0.00000000e+00, 1.25154759e-07,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 3.14291660e-08,
#                   nan, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        2.30874630e-06, 3.92928171e-07, 0.00000000e+00, 2.45558062e-07,
#                   nan, 0.00000000e+00,            nan, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00,            nan,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 4.04282088e-08,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 4.64312210e-07,
#        0.00000000e+00,            nan, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 3.88168992e-03, 2.26101783e-07,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 5.54676642e-07,
#        0.00000000e+00, 1.97579437e-06, 2.77944358e-07, 0.00000000e+00,
#        0.00000000e+00, 3.18185199e-07, 0.00000000e+00, 0.00000000e+00,
#                   nan, 0.00000000e+00, 0.00000000e+00, 4.79440080e-07,
#        4.87415875e-06,            nan, 0.00000000e+00, 3.02747514e-07,
#        7.63501228e-07, 4.33429786e+03, 3.68509234e-06, 0.00000000e+00,
#        9.38005939e-07, 1.64592083e-07, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 3.43174368e-07, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00,            nan,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        1.24553937e-07, 2.99374978e-07, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 3.11795110e-08,
#        0.00000000e+00, 0.00000000e+00, 7.05090612e-08, 9.44418356e-08,
#        4.52626265e-07, 2.72637829e-08, 0.00000000e+00,            nan,
#        0.00000000e+00, 0.00000000e+00, 9.45455607e-08, 0.00000000e+00,
#        9.23300892e-08, 0.00000000e+00, 0.00000000e+00, 3.22370182e-08,
#        0.00000000e+00, 0.00000000e+00, 4.64461664e-08, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00,            nan,
#        0.00000000e+00,            nan, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#                   nan, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00,            nan,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00,            nan,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 1.69189330e-08,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00,            nan, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 8.11305955e-08, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 1.64909285e-06,
#        2.38851748e-07, 0.00000000e+00, 2.11174224e-07, 0.00000000e+00,
#        0.00000000e+00, 5.83989244e-08, 0.00000000e+00, 0.00000000e+00,
#                   nan, 0.00000000e+00, 0.00000000e+00,            nan,
#        0.00000000e+00, 0.00000000e+00,            nan, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00,            nan, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        1.40112419e-07, 0.00000000e+00, 1.86851601e-07, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 1.70231759e-07,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00,            nan,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00,            nan, 0.00000000e+00,
#        8.46088252e-07, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 1.59075230e-06,            nan, 0.00000000e+00,
#                   nan, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00])

# %% [markdown]
# ## Best Predicted Portfolio

# %%
best_portfolio_indices = best_50_index

best_portfolio_mu = df_mu[best_portfolio_indices]
best_portfolio_Q = df_Q[best_portfolio_indices].loc[best_portfolio_indices]

w, ret = MVO(best_portfolio_mu,best_portfolio_Q,gamma=1)

print('Best Predicted MVO Value',ret)
# Out:
# Best Predicted MVO Value [-19.045725812384593]

# %% [markdown]
# ## Random Search Portfolio

# %%
returns = []
for _ in range(2000):
    rand_portfolio_indices = list(np.random.choice(1000, 50, replace=False))

    rand_portfolio_mu = df_mu[rand_portfolio_indices]
    rand_portfolio_Q = df_Q[rand_portfolio_indices].loc[rand_portfolio_indices]

    w, ret = MVO(rand_portfolio_mu,rand_portfolio_Q,gamma=1)

    # print(ret)

    returns.append(ret)

returns = np.array(returns)
print('Best Random Portfolio MVO Vlaue', returns.max())
# Out:
# Best Random Portfolio MVO Vlaue -19.574344604269527

# %% [markdown]
# ## To-Do List

# %% [markdown]
# 0) exponential reward
# 1) add more to state space
# 1.1) sharpe ratio
# 2) add spatial pooling to state space
# 3) change neural networks
# 4) parameter tweeking
# 5) save actor model and call it
# 6) look at the minimum reward of the 50 portfolios at end of each game
